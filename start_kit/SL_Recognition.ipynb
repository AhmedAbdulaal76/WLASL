# %% [markdown]
# # Part1: Data handling

# %% [markdown]
# ### Data splitting

# %%
import json
import os
import shutil
import torch
import torchvision.models as models
import torch.nn as nn
import torchvision.transforms as transforms
import numpy as np

# %%
def organize_data(json_file, videos_folder, output_folder):
    """Organizes video data into training, validation, and testing folders based on JSON file."""

    try:
        with open(json_file, 'r') as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"Error: JSON file '{json_file}' not found.")
        return
    except json.JSONDecodeError:
        print(f"Error: Invalid JSON format in '{json_file}'.")
        return

    os.makedirs(os.path.join(output_folder, "train_data"), exist_ok=True)
    os.makedirs(os.path.join(output_folder, "val_data"), exist_ok=True)
    os.makedirs(os.path.join(output_folder, "test_data"), exist_ok=True)

    for entry in data:
        for instance in entry['instances']:
            video_id = instance['video_id']
            video_path = os.path.join(videos_folder, f"{video_id}.mp4")
            split = instance['split']

            if not os.path.exists(video_path):
                print(f"Warning: Video file '{video_path}' not found. Skipping.")
                continue

            if split == "train":
                destination = os.path.join(output_folder, "training_data", f"{video_id}.mp4")
            elif split == "val":
                destination = os.path.join(output_folder, "validation_data", f"{video_id}.mp4")
            elif split == "test":
                destination = os.path.join(output_folder, "testing_data", f"{video_id}.mp4")
            else:
                print(f"Warning: Unknown split '{split}' for video '{video_id}'. Skipping.")
                continue

            try:
                shutil.copy2(video_path, destination)  # copy2 preserves metadata
                print(f"Copied '{video_id}.mp4' to '{split}' folder.")
            except shutil.Error as e:
                print(f"Error copying '{video_id}.mp4': {e}")

def main():
    json_file_path = 'WLASL_100.json'  # Path to your JSON file
    videos_folder_path = 'videos'  # Path to your videos folder
    output_directory = 'organized_data'  # Path to the output directory

    organize_data(json_file_path, videos_folder_path, output_directory)

if __name__ == "__main__":
    main()
# Out:
# Copied '69241.mp4' to 'train' folder.
# ...
# Copied '07069.mp4' to 'train' folder.
# ...
# Copied '07068.mp4' to 'train' folder.
# ...
# Copied '07070.mp4' to 'train' folder.
# ...
# Copied '07074.mp4' to 'train' folder.
# ...
# Copied '69302.mp4' to 'val' folder.
# ...
# Copied '17710.mp4' to 'train' folder.
# ...
# Copied '65540.mp4' to 'train' folder.
# ...
# Copied '17711.mp4' to 'train' folder.
# Copied '17712.mp4' to 'train' folder.
# Copied '17713.mp4' to 'test' folder.
# ...
# Copied '17709.mp4' to 'train' folder.
# ...
# Copied '17720.mp4' to 'train' folder.
# Copied '17721.mp4' to 'train' folder.
# Copied '17722.mp4' to 'train' folder.
# Copied '17723.mp4' to 'train' folder.
# Copied '17724.mp4' to 'val' folder.
# ...
# Copied '12328.mp4' to 'train' folder.
# ...
# Copied '12312.mp4' to 'val' folder.
# ...
# Copied '12311.mp4' to 'train' folder.
# ...
# Copied '12313.mp4' to 'train' folder.
# Copied '12314.mp4' to 'train' folder.
# Copied '12315.mp4' to 'val' folder.
# Copied '12316.mp4' to 'train' folder.
# Copied '12317.mp4' to 'train' folder.
# ...

# %% [markdown]
# ### Data processing

# %% [markdown]
# #### Videos renaming

# %%
def load_labels(json_file):
    """Loads video labels, creating a dictionary with lists of video IDs per gloss."""
    try:
        with open(json_file, 'r') as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"Error: JSON file '{json_file}' not found.")
        return None
    except json.JSONDecodeError:
        print(f"Error: Invalid JSON format in '{json_file}'.")
        return None

    label_data = {}
    for item in data:
        gloss = item["gloss"]
        for instance in item["instances"]:
            video_id = instance["video_id"]
            if gloss not in label_data:
                label_data[gloss] = []
            label_data[gloss].append(video_id)
    return label_data

# %%
def rename_videos(data_dir, video_info):
    """Renames videos using gloss, video_id, and instance_id from video_info."""
    for subfolder in ["train_data", "val_data", "test_data"]:
        subfolder_path = os.path.join(data_dir, subfolder)
        for video_id, info in video_info.items():
            # Check if the video belongs to the current split
            if info['split'] == subfolder.replace('_data', ''):
                filename = f"{video_id}.mp4"
                old_path = os.path.join(subfolder_path, filename)
                if os.path.exists(old_path):
                    new_filename = f"{info['gloss']}_{video_id}_{info['instance_id']}.mp4"
                    new_path = os.path.join(subfolder_path, new_filename)
                    os.rename(old_path, new_path)
                    print(f"Renamed: {old_path} -> {new_path}")
                else:
                    print(f"Warning: Video file '{filename}' not found in '{subfolder_path}'.")

# %%
# constant directory names
json_file_path = 'WLASL_100.json'
data_dir = 'organized_data'

# %%
def count_unique_classes(folder_path):
    class_names = set()
    for filename in os.listdir(folder_path):
        # Split the filename and get the first part as the class name
        if filename.endswith(".mp4"):
            class_name = filename.split("_")[0]
            class_names.add(class_name)
    
    return len(class_names), class_names

# Replace 'your_folder_path' with the path to your folder containing the videos
folder_path = f'{data_dir}/train_data'
unique_class_count, unique_classes = count_unique_classes(folder_path)

print(f"Number of unique classes: {unique_class_count}")
print("Unique classes:", unique_classes)
# Out:
# Number of unique classes: 100
# Unique classes: {'now', 'paint', 'forget', 'orange', 'full', 'bowling', 'wrong', 'medicine', 'hot', 'eat', 'purple', 'change', 'book', 'later', 'doctor', 'enjoy', 'table', 'finish', 'language', 'cheat', 'mother', 'cousin', 'blue', 'year', 'like', 'bird', 'work', 'give', 'jacket', 'but', 'play', 'white', 'cow', 'time', 'fine', 'candy', 'yes', 'who', 'graduate', 'thin', 'can', 'computer', 'apple', 'family', 'dog', 'hearing', 'right', 'shirt', 'how', 'tall', 'thanksgiving', 'same', 'accident', 'basketball', 'africa', 'birthday', 'what', 'pink', 'kiss', 'decide', 'man', 'deaf', 'city', 'meet', 'woman', 'chair', 'no', 'paper', 'pizza', 'need', 'study', 'bed', 'go', 'last', 'cook', 'help', 'color', 'pull', 'drink', 'tell', 'secretary', 'black', 'all', 'dance', 'clothes', 'fish', 'before', 'short', 'walk', 'brown', 'cool', 'letter', 'want', 'dark', 'thursday', 'son', 'hat', 'many', 'corn', 'school'}

# %%
label_data = load_labels(json_file_path)
if label_data is not None:
    rename_videos(data_dir, label_data)
# Out:
# Renamed: organized_data\train_data\69241.mp4 -> organized_data\train_data\book_69241_0.mp4
# ...
# Renamed: organized_data\train_data\07069.mp4 -> organized_data\train_data\book_07069_10.mp4
# ...
# Renamed: organized_data\train_data\07068.mp4 -> organized_data\train_data\book_07068_17.mp4
# ...
# Renamed: organized_data\train_data\07070.mp4 -> organized_data\train_data\book_07070_22.mp4
# ...
# Renamed: organized_data\train_data\07074.mp4 -> organized_data\train_data\book_07074_29.mp4
# ...
# Renamed: organized_data\train_data\17710.mp4 -> organized_data\train_data\drink_17710_11.mp4
# ...
# Renamed: organized_data\train_data\65540.mp4 -> organized_data\train_data\drink_65540_17.mp4
# ...
# Renamed: organized_data\train_data\17711.mp4 -> organized_data\train_data\drink_17711_19.mp4
# Renamed: organized_data\train_data\17712.mp4 -> organized_data\train_data\drink_17712_20.mp4
# ...
# Renamed: organized_data\train_data\17709.mp4 -> organized_data\train_data\drink_17709_27.mp4
# ...

# %% [markdown]
# #### Video information

# %%
def load_video_info(json_file):
    """Loads video information such as FPS and frame range."""
    try:
        with open(json_file, 'r') as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"Error: JSON file '{json_file}' not found.")
        return None
    except json.JSONDecodeError:
        print(f"Error: Invalid JSON format in '{json_file}'.")
        return None

    video_info = {}
    for item in data:
        gloss = item["gloss"]
        for instance in item["instances"]:
            video_id = instance["video_id"]
            fps = instance["fps"]
            frame_start = instance["frame_start"]
            frame_end = instance["frame_end"]
            split = instance["split"]
            instance_id = instance["instance_id"]

            if video_id not in video_info:
                video_info[video_id] = {
                    "gloss": gloss,
                    "fps": fps,
                    "frame_start": frame_start,
                    "frame_end": frame_end,
                    "split": split,
                    "instance_id": instance_id
                }
    return video_info

# %%
# this variable contain the {gloss, fps, frame_start, frame_end, split} information for each instance
video_info = load_video_info(json_file_path)

# %%
print(video_info)
# Out:
# {'69241': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 0}, '65225': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 1}, '68011': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 2}, '68208': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': 60, 'split': 'train', 'instance_id': 3}, '68012': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 4}, '70212': {'gloss': 'book', 'fps': 25, 'frame_start': 2150, 'frame_end': 2249, 'split': 'val', 'instance_id': 5}, '70266': {'gloss': 'book', 'fps': 25, 'frame_start': 3732, 'frame_end': 3852, 'split': 'train', 'instance_id': 6}, '07085': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 7}, '07086': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 8},
# ...

# %%
# the new renaming function

def rename_videos(data_dir, video_info):
    """Renames videos using gloss, video_id, and instance_id from video_info."""
    for subfolder in ["train_data", "val_data", "test_data"]:
        subfolder_path = os.path.join(data_dir, subfolder)
        for video_id, info in video_info.items():
            # Check if the video belongs to the current split
            if info['split'] == subfolder.replace('_data', ''):
                filename = f"{video_id}.mp4"
                old_path = os.path.join(subfolder_path, filename)
                if os.path.exists(old_path):
                    new_filename = f"{info['gloss']}_{video_id}_{info['instance_id']}.mp4"
                    new_path = os.path.join(subfolder_path, new_filename)
                    os.rename(old_path, new_path)
                    print(f"Renamed: {old_path} -> {new_path}")
                else:
                    print(f"Warning: Video file '{filename}' not found in '{subfolder_path}'.")

# %%
rename_videos(data_dir, video_info)
# Out:
# Renamed: organized_data\train_data\69241.mp4 -> organized_data\train_data\book_69241_0.mp4
# ...
# Renamed: organized_data\train_data\07069.mp4 -> organized_data\train_data\book_07069_10.mp4
# ...
# Renamed: organized_data\train_data\07068.mp4 -> organized_data\train_data\book_07068_17.mp4
# ...
# Renamed: organized_data\train_data\07070.mp4 -> organized_data\train_data\book_07070_22.mp4
# ...
# Renamed: organized_data\train_data\07074.mp4 -> organized_data\train_data\book_07074_29.mp4
# ...
# Renamed: organized_data\train_data\17710.mp4 -> organized_data\train_data\drink_17710_11.mp4
# ...
# Renamed: organized_data\train_data\65540.mp4 -> organized_data\train_data\drink_65540_17.mp4
# Renamed: organized_data\train_data\17711.mp4 -> organized_data\train_data\drink_17711_19.mp4
# Renamed: organized_data\train_data\17712.mp4 -> organized_data\train_data\drink_17712_20.mp4
# ...
# Renamed: organized_data\train_data\17709.mp4 -> organized_data\train_data\drink_17709_27.mp4
# ...

# %% [markdown]
# #### Frame extraction

# %%
# Libraries of the section
import cv2

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
def extract_frames(video_path, fps, frame_start, frame_end):
    """Extracts frames from a video, handling variable frame_end values."""
    cap = cv2.VideoCapture(video_path)
    frames = []
    current_frame = 0

    if not cap.isOpened():
        print(f"Error: Could not open video file {video_path}")
        return []

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        if current_frame >= frame_start:
            frames.append(frame)
            if frame_end != -1 and current_frame >= frame_end:
                break  # Stop if frame_end is specified and reached

        current_frame += 1

    cap.release()
    return frames

def downsample_or_upsample_frames(frames, current_fps, target_fps):
    """Downsamples or upsamples frames based on the current and target FPS."""
    if current_fps == target_fps:
        return frames

    if current_fps < target_fps:
        # Upsample: Repeat frames to increase frame rate
        factor = target_fps // current_fps
        new_frames = []
        for frame in frames:
            new_frames.extend([frame] * factor)
        return new_frames
    else:
        # Downsample: Skip frames to decrease frame rate
        factor = current_fps // target_fps
        return frames[::factor]

def create_sequences(frames, sequence_length):
    """Creates sequences of frames from a list of frames."""
    sequences = []
    for i in range(len(frames) - sequence_length + 1):
        sequence = frames[i:i + sequence_length]
        sequences.append(sequence)
    return sequences

# %% [markdown]
# #### Features Extraction

# %%
# Libraries of th section

import torch
import torchvision.models as models
import torch.nn as nn
import torchvision.transforms as transforms
import numpy as np

# %%
def extract_resnet_features(frames, resnet_model, transform, device, batch_size=32):
    """Extracts 2048-dimensional ResNet features from a sequence of frames."""
    features = []
    tensors = []

    # Preprocess all frames first
    for frame in frames:
        img_tensor = transform(frame)
        tensors.append(img_tensor)

    # Create batches
    num_batches = int(np.ceil(len(tensors) / batch_size))

    for i in range(num_batches):
        batch_tensors = tensors[i * batch_size:(i + 1) * batch_size]
        batch_tensors = torch.stack(batch_tensors).to(device)  # Stack and move to GPU

        with torch.no_grad():
            outputs = resnet_model(batch_tensors)  # Shape: (batch_size, 2048, 1, 1)
            outputs = outputs.view(outputs.size(0), -1)  # Flatten to (batch_size, 2048)

        features.extend(outputs.cpu().numpy())

    return features

def preprocess_and_extract_features(data_dir, video_info, target_fps=25, sequence_length=32):
    """Preprocesses videos, extracts frames, and features."""
    # Load ResNet50 and remove the final classification layer
    resnet_model = models.resnet50(pretrained=True)
    resnet_model = nn.Sequential(*list(resnet_model.children())[:-1])  # Exclude the last layer
    resnet_model.eval()
    resnet_model.to(device)  # Move model to GPU

    transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])

    datasets = {
        "train": {"features": [], "labels": []},
        "val": {"features": [], "labels": []},
        "test": {"features": [], "labels": []}
    }

    missing_videos = []
    missing_labels = []

    for video_id, info in video_info.items():
        split = info['split']  # "train", "val", or "test"
        gloss = info['gloss']
        video_path = os.path.join(data_dir, f"{split}_data", f"{gloss}_{video_id}_{info['instance_id']}.mp4")

        if not os.path.exists(video_path):
            missing_videos.append(video_path)
            continue

        # Extract frames
        frames = extract_frames(video_path, info['fps'], info['frame_start'], info['frame_end'])
        if not frames:
            missing_labels.append(gloss)
            continue

        # Downsample/Upsample frames and create sequences
        frames = downsample_or_upsample_frames(frames, info['fps'], target_fps)
        sequences = create_sequences(frames, sequence_length)
        if not sequences:
            missing_labels.append(gloss)
            continue

        # Extract features for each sequence
        for sequence in sequences:
            features = extract_resnet_features(sequence, resnet_model, transform, device)
            datasets[split]["features"].append(features)
            datasets[split]["labels"].append(gloss)

    # Log missing videos and labels for debugging
    if missing_videos:
        print(f"Missing video files: {len(missing_videos)}")
    if missing_labels:
        print(f"Missing labels: {len(missing_labels)}")

    return (
        datasets["train"]["features"], datasets["train"]["labels"],
        datasets["val"]["features"], datasets["val"]["labels"],
        datasets["test"]["features"], datasets["test"]["labels"]
    )

# %%
# all_features, all_labels = preprocess_and_extract_features(data_dir, video_info)
train_features, train_labels, val_features, val_labels, test_features, test_labels = preprocess_and_extract_features(data_dir, video_info)
# Out:
# Missing video files: 1162
# Missing labels: 97

# %%
# print(all_features)
print(train_features)
print(val_features)
print(test_features)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[125], line 2
#       1 # print(all_features)
# ----> 2 print(train_features)
#       3 print(val_features)
#       4 print(test_features)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\_core\arrayprint.py:1565, in _array_repr_implementation(arr, max_line_width, precision, suppress_small, array2string)
#    1563     lst = repr(arr.item())
#    1564 elif arr.size > 0 or arr.shape == (0,):
# -> 1565     lst = array2string(arr, max_line_width, precision, suppress_small,
#    1566                        ', ', prefix, suffix=suffix)
#    1567 else:  # show zero-length shape unless it is (0,)
#    1568     lst = "[], shape=%s" % (repr(arr.shape),)
#
# ...

# %%
# print(all_labels)
print(len(set(train_labels)))
# Out:
# 100

# %%
np.save("unique_classes.npy", np.unique(unique_classes))

# %%
# Assume all_features and all_labels have been generated by the function
# Save all_features
# np.save('all_features.npy', all_features)
np.save('train_features.npy', train_features)
np.save('val_features.npy', val_features)
np.save('test_features.npy', test_features)


# Save all_labels
# np.save('all_labels.npy', all_labels)
np.save('train_labels.npy', train_labels)
np.save('val_labels.npy', val_labels)
np.save('test_labels.npy', test_labels)

# %%
# Loading the saved features and labels
all_features = np.load('all_features.npy', allow_pickle=True)
all_labels = np.load('all_labels.npy', allow_pickle=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[55], line 2
#       1 # Loading the saved features and labels
# ----> 2 all_features = np.load('all_features.npy', allow_pickle=True)
#       3 all_labels = np.load('all_labels.npy', allow_pickle=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_npyio_impl.py:455, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     453     own_fid = False
#     454 else:
# --> 455     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     456     own_fid = True
#     458 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'all_features.npy'

# %%
unique_classes = np.load('unique_classes.npy', allow_pickle=True)

# %%
train_features = np.load('train_features.npy', allow_pickle=True)
train_labels = np.load('train_labels.npy', allow_pickle=True)

# %%
val_features = np.load('val_features.npy', allow_pickle=True)
val_labels = np.load('val_labels.npy', allow_pickle=True)

# %%
test_features = np.load('test_features.npy', allow_pickle=True)
test_labels = np.load('test_labels.npy', allow_pickle=True)

# %%
# print("Shape of all_features:", np.array(all_features).shape)
print('Shape of train_features:', np.array(train_features).shape)
print('Shape of val_features:', np.array(val_features).shape)
print('Shape of test_features:', np.array(test_features).shape)
# Out:
# Shape of train_features: (19406, 32, 2048)
# Shape of val_features: (4763, 32, 2048)
# Shape of test_features: (3010, 32, 2048)

# %%
sequence_length = 32

# %%
# all_features = np.array(all_features)
# assert all_features.shape[1] == sequence_length, "Sequence length mismatch"
# assert all_features.shape[2] == 2048, "Feature dimension mismatch"

# %%
# # label_to_index = {label: idx for idx, label in enumerate(all_labels)}
# # numerical_labels = [label_to_index[label] for label in all_labels] # Convert labels to numerical indices
# train_labels_to_index = {label: idx for idx, label in enumerate(train_labels)}
# train_numerical_labels = [train_labels_to_index[label] for label in train_labels] # Convert labels to numerical indices
# val_labels_to_index = {label: idx for idx, label in enumerate(val_labels)}
# val_numerical_labels = [val_labels_to_index[label] for label in val_labels] # Convert labels to numerical indices
# test_labels_to_index = {label: idx for idx, label in enumerate(test_labels)}
# test_numerical_labels = [test_labels_to_index[label] for label in test_labels] # Convert labels to numerical indices

# %% [markdown]
# ## Data loading

# %%
# Libraries of the section
from torch.utils.data import Dataset
import torchvision.transforms as transforms
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import LabelEncoder

# %%
class SignLanguageDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.tensor(features, dtype=torch.float32)
        self.labels = torch.tensor(labels, dtype=torch.long)  # Use torch.long for class indices

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]

# %%
# dataset = SignLanguageDataset(all_features, numerical_labels)

# %%
# Define the augmentation pipeline
augmentation_transforms = transforms.Compose([
    transforms.RandomResizedCrop(size=(224, 224), scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomRotation(degrees=15),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
class AugmentedSignLanguageDataset(Dataset):
    def __init__(self, features, labels, transform=None):
        self.features = features  # Assuming features are lists of PIL Images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        frames = self.features[idx]
        label = self.labels[idx]

        if self.transform:
            augmented_frames = [self.transform(frame) for frame in frames]
            augmented_frames = torch.stack(augmented_frames)  # Shape: (sequence_length, C, H, W)
        else:
            augmented_frames = torch.stack([transforms.ToTensor()(frame) for frame in frames])

        return augmented_frames, label

# %%
# # Initialize datasets
# # train_dataset = SignLanguageDataset(train_features, train_numerical_labels)
# train_dataset = AugmentedSignLanguageDataset(train_features, train_numerical_labels, transform=augmentation_transforms)
# val_dataset = SignLanguageDataset(val_features, val_numerical_labels)
# test_dataset = SignLanguageDataset(test_features, test_numerical_labels)

# %%
batch_size = 64 # Adjust based on your system's capacity

# # Create DataLoaders
# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
# val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
# test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# label_encoder = LabelEncoder()
# all_encoded_labels = label_encoder.fit_transform(all_labels)

# # Convert to tensors
# all_features_tensor = torch.tensor(all_features, dtype=torch.float32)
# all_labels_tensor = torch.tensor(all_encoded_labels, dtype=torch.long)

# # Create a TensorDataset and DataLoader
# all_dataset = TensorDataset(all_features_tensor, all_labels_tensor)
# all_loader = DataLoader(all_dataset, batch_size=batch_size, shuffle=True)

# %%
string_labels = {str(label) for label in train_labels}
print(sorted(list(string_labels)))

print(set.difference(set(unique_classes[0]), set(string_labels)))
# Out:
# ['accident', 'africa', 'all', 'apple', 'basketball', 'bed', 'before', 'bird', 'birthday', 'black', 'blue', 'book', 'bowling', 'brown', 'but', 'can', 'candy', 'chair', 'change', 'cheat', 'city', 'clothes', 'color', 'computer', 'cook', 'cool', 'corn', 'cousin', 'cow', 'dance', 'dark', 'deaf', 'decide', 'doctor', 'dog', 'drink', 'eat', 'enjoy', 'family', 'fine', 'finish', 'fish', 'forget', 'full', 'give', 'go', 'graduate', 'hat', 'hearing', 'help', 'hot', 'how', 'jacket', 'kiss', 'language', 'last', 'later', 'letter', 'like', 'man', 'many', 'medicine', 'meet', 'mother', 'need', 'no', 'now', 'orange', 'paint', 'paper', 'pink', 'pizza', 'play', 'pull', 'purple', 'right', 'same', 'school', 'secretary', 'shirt', 'short', 'son', 'study', 'table', 'tall', 'tell', 'thanksgiving', 'thin', 'thursday', 'time', 'walk', 'want', 'what', 'white', 'who', 'woman', 'work', 'wrong', 'year', 'yes']
# set()

# %%
print((list(unique_classes[0])))
# Out:
# ['who', 'hat', 'forget', 'hearing', 'dog', 'bird', 'kiss', 'dark', 'right', 'black', 'drink', 'son', 'mother', 'work', 'paint', 'full', 'shirt', 'no', 'fish', 'cook', 'corn', 'bed', 'candy', 'birthday', 'bowling', 'go', 'study', 'later', 'man', 'many', 'yes', 'computer', 'play', 'fine', 'purple', 'pink', 'before', 'doctor', 'table', 'cousin', 'secretary', 'brown', 'walk', 'clothes', 'can', 'need', 'orange', 'thanksgiving', 'pizza', 'tall', 'school', 'chair', 'language', 'graduate', 'decide', 'what', 'apple', 'basketball', 'color', 'africa', 'eat', 'year', 'letter', 'cool', 'book', 'woman', 'blue', 'give', 'paper', 'same', 'thursday', 'wrong', 'like', 'last', 'pull', 'help', 'city', 'want', 'but', 'short', 'meet', 'now', 'medicine', 'cheat', 'time', 'hot', 'all', 'enjoy', 'change', 'deaf', 'cow', 'white', 'family', 'how', 'accident', 'finish', 'thin', 'dance', 'tell', 'jacket']

# %%
print((train_labels[:4]))
print(len(train_labels))
print(len(set(train_labels)))
print((unique_classes))
# Out:
# ['book', 'book', 'book', 'book']
# 19406
# 100
# [{'who', 'hat', 'forget', 'hearing', 'dog', 'bird', 'kiss', 'dark', 'right', 'black', 'drink', 'son', 'mother', 'work', 'paint', 'full', 'shirt', 'no', 'fish', 'cook', 'corn', 'bed', 'candy', 'birthday', 'bowling', 'go', 'study', 'later', 'man', 'many', 'yes', 'computer', 'play', 'fine', 'purple', 'pink', 'before', 'doctor', 'table', 'cousin', 'secretary', 'brown', 'walk', 'clothes', 'can', 'need', 'orange', 'thanksgiving', 'pizza', 'tall', 'school', 'chair', 'language', 'graduate', 'decide', 'what', 'apple', 'basketball', 'color', 'africa', 'eat', 'year', 'letter', 'cool', 'book', 'woman', 'blue', 'give', 'paper', 'same', 'thursday', 'wrong', 'like', 'last', 'pull', 'help', 'city', 'want', 'but', 'short', 'meet', 'now', 'medicine', 'cheat', 'time', 'hot', 'all', 'enjoy', 'change', 'deaf', 'cow', 'white', 'family', 'how', 'accident', 'finish', 'thin', 'dance', 'tell', 'jacket'}]

# %%
label_encoder = LabelEncoder()

label_encoder.fit(list(unique_classes[0]))
# Out:
# LabelEncoder()

# %%
# label_encoder = LabelEncoder()
# Assuming train_labels is a list or numpy array of your labels
train_encoded_labels = label_encoder.transform(train_labels)

# Convert to tensors
features_tensor = torch.tensor(train_features, dtype=torch.float32)
labels_tensor = torch.tensor(train_encoded_labels, dtype=torch.long)

# Create a TensorDataset and DataLoader
train_dataset = TensorDataset(features_tensor, labels_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
# Out:
# C:\Users\Hayder\AppData\Local\Temp\ipykernel_24068\2969976997.py:6: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:281.)
#   features_tensor = torch.tensor(train_features, dtype=torch.float32)

# %%
# label_encoder = LabelEncoder()
val_encoded_labels = label_encoder.transform(val_labels)

# Convert to tensors
val_features_tensor = torch.tensor(val_features, dtype=torch.float32)
val_labels_tensor = torch.tensor(val_encoded_labels, dtype=torch.long)

# Create a TensorDataset and DataLoader
val_dataset = TensorDataset(val_features_tensor, val_labels_tensor)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
# label_encoder = LabelEncoder()
test_encoded_labels = label_encoder.transform(test_labels)

# Convert to tensors
test_features_tensor = torch.tensor(test_features, dtype=torch.float32)
test_labels_tensor = torch.tensor(test_encoded_labels, dtype=torch.long)

# Create a TensorDataset and DataLoader
test_dataset = TensorDataset(test_features_tensor, test_labels_tensor)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
print(features_tensor.dtype)
print(labels_tensor.dtype)

print(test_features_tensor.dtype)
print(test_labels_tensor.dtype)
# Out:
# torch.float32
# torch.int64
# torch.float32
# torch.int64

# %% [markdown]
# ### Model Definition

# %%
import torch
import torch.nn as nn

import torch
import torch.nn as nn
import torch.nn.functional as F

class SignLanguageLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes, num_layers=1, dropout=0.5):
        super(SignLanguageLSTM, self).__init__()

        # Bidirectional LSTM with reduced hidden size and layers
        self.lstm = nn.LSTM(
            input_size, hidden_size, num_layers,
            batch_first=True, bidirectional=True
        )

        # Layer normalization
        self.layer_norm = nn.LayerNorm(hidden_size * 2)

        # Fully connected layers with gradual dimension reduction
        self.fc1 = nn.Linear(hidden_size * 2, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, num_classes)

        # Dropout layer
        self.dropout = nn.Dropout(dropout)

        # Initialize weights
        self.init_weights()

    def forward(self, x):
        # LSTM forward pass
        lstm_out, _ = self.lstm(x)

        # Apply LayerNorm to LSTM outputs
        lstm_out = self.layer_norm(lstm_out)

        # Mean pooling over time steps
        out = torch.mean(lstm_out, dim=1)

        # Apply dropout
        out = self.dropout(out)

        # Fully connected layers with activation functions
        out = F.relu(self.fc1(out))
        out = self.dropout(out)
        out = F.relu(self.fc2(out))
        out = self.fc3(out)

        return out

    def init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.LSTM):
                for name, param in m.named_parameters():
                    if 'weight' in name:
                        nn.init.xavier_uniform_(param)
                    elif 'bias' in name:
                        nn.init.zeros_(param)

# %% [markdown]
# #### Model initialization

# %% [markdown]
# #### Training loop

# %%
def train_and_evaluate_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=20, patience=5, use_early_stopping=True):
    """ Train and evaluate the model.
    
    Args:
        model: The neural network model to train.
        train_loader: DataLoader for the training dataset.
        val_loader: DataLoader for the validation dataset.
        criterion: The loss function.
        optimizer: The optimizer for model training.
        num_epochs: Number of epochs for training (default is 20).
        patience: Number of epochs to wait for improvement before early stopping (default is 5).
        use_early_stopping: Whether to use early stopping (default is True).

    Returns:
        Lists of training losses, validation losses, training accuracies, and validation accuracies.
    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    best_val_loss = float('inf')
    epochs_without_improvement = 0
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_predictions = 0
        total_predictions = 0

        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item() * features.size(0)
            _, predicted = torch.max(outputs, 1)
            correct_predictions += (predicted == labels).sum().item()
            total_predictions += labels.size(0)

        epoch_loss = running_loss / total_predictions
        epoch_accuracy = correct_predictions / total_predictions
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_accuracy)

        model.eval()
        val_running_loss = 0.0
        val_correct_predictions = 0
        val_total_predictions = 0

        with torch.no_grad():
            for val_features, vali_labels in val_loader:
                val_features, vali_labels = val_features.to(device), vali_labels.to(device)
                val_outputs = model(val_features)
                val_loss = criterion(val_outputs, vali_labels)
                val_running_loss += val_loss.item() * val_features.size(0)
                _, val_predicted = torch.max(val_outputs, 1)
                val_correct_predictions += (val_predicted == vali_labels).sum().item()
                val_total_predictions += vali_labels.size(0)

        val_epoch_loss = val_running_loss / val_total_predictions
        val_epoch_accuracy = val_correct_predictions / val_total_predictions
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_accuracy)

        print(f"Epoch [{epoch + 1}/{num_epochs}], "
              f"Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_accuracy:.4f}, "
              f"Val Loss: {val_epoch_loss:.4f}, Val Accuracy: {val_epoch_accuracy:.4f}")

        if use_early_stopping:
            if val_epoch_loss < best_val_loss:
                best_val_loss = val_epoch_loss
                epochs_without_improvement = 0
                # Save the best model
                # torch.save(model.state_dict(), 'best_model.pth')
            else:
                epochs_without_improvement += 1
                if epochs_without_improvement >= patience:
                    print("Early stopping triggered. Stopping training.")
                    break

    return train_losses, val_losses, train_accuracies, val_accuracies

# %%
print(set.difference(set(train_labels), set(test_labels)))
print(set.difference(set(train_labels), set(val_labels)))

print(set.difference(set(test_labels), set(train_labels)))
print(set.difference(set(val_labels), set(train_labels)))
# Out:
# {'hat', 'need', 'study', 'orange', 'school', 'later', 'chair', 'man', 'many', 'graduate', 'decide', 'apple', 'fine', 'medicine', 'hot', 'black', 'eat', 'enjoy', 'pink', 'cool', 'son', 'mother', 'cow', 'book', 'family', 'blue', 'paint', 'paper', 'table', 'finish', 'thursday', 'wrong', 'cook', 'dance', 'bed', 'jacket', 'walk'}
# {'last', 'forget', 'study', 'hearing', 'kiss', 'medicine', 'all', 'before', 'book', 'paper', 'table', 'wrong', 'dance', 'corn', 'secretary', 'brown', 'candy', 'birthday', 'clothes'}
# set()
# set()

# %% [markdown]
# ### Hyperparameters of the model

# %%
input_size = 2048  # This matches the feature size from your ResNet
hidden_size = 512 #{256,512}
num_classes = 100  # Number of unique classes
num_layers = 3 #{2,3}
dropout = 0.5 #{0.2, 0.3, 0.4, 0.5}

# Initialize the model
model = SignLanguageLSTM(input_size, hidden_size, num_classes, num_layers, dropout)

# Loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5, weight_decay=1e-4)

# %%
# Train the model
train_losses, val_losses, train_accuracies, val_accuracies = train_and_evaluate_model(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    num_epochs=20,
    patience=5,
    use_early_stopping=False
)
# Out:
# Epoch [1/20], Train Loss: 4.7149, Train Accuracy: 0.0186, Val Loss: 4.6085, Val Accuracy: 0.0002
# Epoch [2/20], Train Loss: 4.5138, Train Accuracy: 0.0358, Val Loss: 4.6310, Val Accuracy: 0.0036
# Epoch [3/20], Train Loss: 4.2054, Train Accuracy: 0.0870, Val Loss: 4.8007, Val Accuracy: 0.0414
# Epoch [4/20], Train Loss: 3.7311, Train Accuracy: 0.1680, Val Loss: 4.9398, Val Accuracy: 0.0386
# Epoch [5/20], Train Loss: 3.2060, Train Accuracy: 0.2718, Val Loss: 5.1013, Val Accuracy: 0.0363
# Epoch [6/20], Train Loss: 2.6975, Train Accuracy: 0.3730, Val Loss: 5.3457, Val Accuracy: 0.0477
# Epoch [7/20], Train Loss: 2.2461, Train Accuracy: 0.4763, Val Loss: 5.4150, Val Accuracy: 0.0531
# Epoch [8/20], Train Loss: 1.8676, Train Accuracy: 0.5611, Val Loss: 5.5260, Val Accuracy: 0.0487
# Epoch [9/20], Train Loss: 1.5276, Train Accuracy: 0.6408, Val Loss: 5.7848, Val Accuracy: 0.0563
# Epoch [10/20], Train Loss: 1.2510, Train Accuracy: 0.7024, Val Loss: 5.9292, Val Accuracy: 0.0626
# ...

# %%
class CNNLSTMModel(nn.Module):
    def __init__(self, num_classes):
        super(CNNLSTMModel, self).__init__()
        self.cnn = models.resnet18(pretrained=True)
        self.cnn.fc = nn.Identity()  # Remove the last layer
        self.lstm = nn.LSTM(input_size=512, hidden_size=256, num_layers=2, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(256 * 2, num_classes)

    def forward(self, x):
        batch_size, seq_length, c, h, w = x.size()
        x = x.view(batch_size * seq_length, c, h, w)
        cnn_features = self.cnn(x)
        cnn_features = cnn_features.view(batch_size, seq_length, -1)
        lstm_out, _ = self.lstm(cnn_features)
        out = lstm_out[:, -1, :]
        out = self.fc(out)
        return out

# %%
# num_classes = len(set(train_numerical_labels))
# print(f"Number of classes: {num_classes}")
print(device)
torch.cuda.empty_cache()
# Out:
# cuda

# %%
print("Number of training labels:", len(train_labels))
print("Unique training labels:", len(set(train_labels)))
print("Number of validation labels:", len(val_labels))
print("Unique validation labels:", len(set(val_labels)))
print("Number of test labels:", len(test_labels))
print("Unique test labels:", len(set(test_labels)))
# Out:
# Number of training labels: 19406
# Unique training labels: 100
# Number of validation labels: 4763
# Unique validation labels: 81
# Number of test labels: 3010
# Unique test labels: 63

# %% [markdown]
# #### Plots

# %%
import matplotlib.pyplot as plt
 
# Plot loss
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
 
# Plot accuracy
plt.figure(figsize=(10, 5))
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.title('Accuracy vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Testing the model

# %%
def evaluate_model(model, loader):
    model.eval()
    correct = 0
    total = 0
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)
    accuracy = correct / total
    return accuracy

# %%
test_accuracy = evaluate_model(model, test_loader)*100
print(f"Test accuracy: {test_accuracy:.4f}%")
# Out:
# Test accuracy: 7.0100%

# %%
def filter_video_info(video_info, data_dir):
    filtered_video_info = []
    missing_files = []
    for video_id, info in video_info.items():
        gloss = info['gloss']
        split = info['split']
        instance_id = info['instance_id']
        video_path = os.path.join(data_dir, f"{split}_data", f"{gloss}_{video_id}_{instance_id}.mp4")
        if os.path.exists(video_path):
            info_copy = info.copy()
            info_copy['video_id'] = video_id
            info_copy['video_path'] = video_path
            filtered_video_info.append(info_copy)
        else:
            missing_files.append(video_path)
    if missing_files:
        print(f"Total missing files: {len(missing_files)}")
    return filtered_video_info

# %%
filtered_video_info = filter_video_info(video_info, data_dir)
all_labels = [info['gloss'] for info in filtered_video_info]
# Out:
# Total missing files: 1162

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
label_encoder.fit(all_labels)
num_classes = len(label_encoder.classes_)
print(f"Number of classes after filtering: {num_classes}")
# Out:
# Number of classes after filtering: 100

# %%
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import LabelEncoder

# Assuming you have already loaded `video_info` and `data_dir`

# Collect all labels and fit LabelEncoder
all_labels = [info['gloss'] for info in video_info.values()]
label_encoder = LabelEncoder()
label_encoder.fit(all_labels)
num_classes = len(label_encoder.classes_)

# Define the transform
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Define the dataset class
class VideoDataset(Dataset):
    def __init__(self, video_info, data_dir, sequence_length=32, transform=None, split='train'):
        self.data_dir = data_dir  # Ensure data_dir is assigned
        self.sequence_length = sequence_length
        self.transform = transform
        self.split = split
        self.video_info = [info for info in video_info if info['split'] == split]
        print(f"{split.capitalize()} dataset size: {len(self.video_info)} samples")

    def __len__(self):
        return len(self.video_info)

    def __getitem__(self, idx):
        try:
            info = self.video_info[idx]
            gloss = info['gloss']
            video_id = info['video_id']
            instance_id = info['instance_id']
            video_path = os.path.join(self.data_dir, f"{self.split}_data", f"{gloss}_{video_id}_{instance_id}.mp4")
            # print(f"Processing video: {video_path}")

            # Extract frames from video
            frames = extract_frames(video_path, info['fps'], info['frame_start'], info['frame_end'])
            if not frames:
                raise ValueError(f"No frames extracted from {video_path}")

            # Downsample/Upsample frames
            frames = downsample_or_upsample_frames(frames, info['fps'], target_fps=25)

            # Create sequences
            sequences = create_sequences(frames, self.sequence_length)
            if not sequences:
                raise ValueError(f"No sequences created from {video_path}")

            # Select the first sequence
            sequence = sequences[0]

            # Apply transformations
            if self.transform:
                sequence = [self.transform(frame) for frame in sequence]

            # Stack frames to create a tensor
            sequence_tensor = torch.stack(sequence)  # Shape: (sequence_length, 3, H, W)

            # Encode label
            label = label_encoder.transform([gloss])[0]

            return sequence_tensor, label

        except Exception as e:
            # print(f"Error processing index {idx}: {e}")
            return None  # Return None to be filtered out by collate_fn

# %%
def collate_fn(batch):
    # Filter out None samples
    batch = [item for item in batch if item is not None]
    if not batch:
        return None  # Return None when the batch is empty
    return torch.utils.data.default_collate(batch)

# %%
# Create datasets
train_dataset2 = VideoDataset(filtered_video_info, data_dir, sequence_length=32, transform=transform, split='train')
val_dataset2 = VideoDataset(filtered_video_info, data_dir, sequence_length=32, transform=transform, split='val')
test_dataset2 = VideoDataset(filtered_video_info, data_dir, sequence_length=32, transform=transform, split='test')

# Create data loaders
batch_size = 4
train_loader2 = DataLoader(train_dataset2, batch_size=batch_size, shuffle=True, num_workers=0, collate_fn=collate_fn)
val_loader2 = DataLoader(val_dataset2, batch_size=batch_size, shuffle=False, num_workers=0, collate_fn=collate_fn)
test_loader2 = DataLoader(test_dataset2, batch_size=batch_size, shuffle=False, num_workers=0, collate_fn=collate_fn)
# Out:
# Train dataset size: 642 samples
# Val dataset size: 146 samples
# Test dataset size: 88 samples

# %%
import torch
from torch.utils.data import DataLoader
import time

def train_and_evaluate_model2(model, train_loader, val_loader, criterion, optimizer, num_epochs=20, patience=5, use_early_stopping=True):
    """
    Trains and evaluates the model.

    Parameters:
        model (nn.Module): The neural network model to train.
        train_loader (DataLoader): DataLoader for training data.
        val_loader (DataLoader): DataLoader for validation data.
        criterion: Loss function.
        optimizer: Optimizer for model parameters.
        num_epochs (int): Maximum number of epochs for training.
        patience (int): Number of epochs to wait for improvement before early stopping.
        use_early_stopping (bool): Whether to use early stopping.

    Returns:
        Tuple containing training losses, validation losses, training accuracies, and validation accuracies.
    """
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    best_val_loss = float('inf')
    epochs_without_improvement = 0

    for epoch in range(num_epochs):
        start_time = time.time()
        model.train()
        running_loss = 0.0
        correct_predictions = 0
        total_predictions = 0
        skipped_batches = 0

        for batch in train_loader:
            if batch is None:
                skipped_batches += 1
                continue
            features, labels = batch
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * features.size(0)
            _, preds = torch.max(outputs, 1)
            correct_predictions += torch.sum(preds == labels)
            total_predictions += labels.size(0)

        train_loss = running_loss / total_predictions
        train_accuracy = correct_predictions.double() / total_predictions
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy.item())

        # Validation phase
        model.eval()
        val_running_loss = 0.0
        val_correct_predictions = 0
        val_total_predictions = 0
        with torch.no_grad():
            for batch in val_loader:
                if batch is None:
                    continue
                features, labels = batch
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                loss = criterion(outputs, labels)

                val_running_loss += loss.item() * features.size(0)
                _, preds = torch.max(outputs, 1)
                val_correct_predictions += torch.sum(preds == labels)
                val_total_predictions += labels.size(0)

        val_loss = val_running_loss / val_total_predictions
        val_accuracy = val_correct_predictions.double() / val_total_predictions
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy.item())

        epoch_time = time.time() - start_time

        print(f"Epoch [{epoch + 1}/{num_epochs}] "
              f"Train Loss: {train_loss:.4f} Train Acc: {train_accuracy:.4f} "
              f"Val Loss: {val_loss:.4f} Val Acc: {val_accuracy:.4f} "
              f"Time: {epoch_time:.2f}s Skipped Batches: {skipped_batches}")

        # Early stopping logic
        if use_early_stopping:
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                epochs_without_improvement = 0
                # Save the best model weights
                best_model_state = model.state_dict()
            else:
                epochs_without_improvement += 1
                if epochs_without_improvement >= patience:
                    print("Early stopping triggered.")
                    # Load the best model weights
                    model.load_state_dict(best_model_state)
                    break

    return train_losses, val_losses, train_accuracies, val_accuracies

# %%
# Instantiate the model with the correct number of classes
model2 = CNNLSTMModel(num_classes)
model2.to(device)

# Loss function and optimizer
criterion2 = nn.CrossEntropyLoss()
optimizer2 = torch.optim.Adam(model2.parameters(), lr=1e-4, weight_decay=1e-4)

# Train the model
train_losses, val_losses, train_accuracies, val_accuracies = train_and_evaluate_model2(
    model2,
    train_loader2,
    val_loader2,
    criterion2,
    optimizer2,
    num_epochs=20,
    patience=5,
    use_early_stopping=True
)
# Out:
# Processing video: organized_data\train_data\mother_36929_14.mp4
# C:\Users\Hayder\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Hayder\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Processing video: organized_data\train_data\dark_14680_9.mp4
# ...

# %%
print("Training loop results:\n")
for i in range(len(train_losses)):
    print(f"Epoch {i + 1}:  Train Loss: {train_losses[i]:.4f}, Train Acc: {train_accuracies[i]:.4f},  "
          f" Val Loss: {val_losses[i]:.4f}, Val Acc: {val_accuracies[i]:.4f}")
# Out:
# Training loop results:
#
# Epoch 1:  Train Loss: 4.6230, Train Acc: 0.0087,   Val Loss: 4.6112, Val Acc: 0.0076
# Epoch 2:  Train Loss: 4.5303, Train Acc: 0.0244,   Val Loss: 4.5429, Val Acc: 0.0611
# Epoch 3:  Train Loss: 4.3783, Train Acc: 0.0558,   Val Loss: 4.4529, Val Acc: 0.0458
# Epoch 4:  Train Loss: 4.1330, Train Acc: 0.0820,   Val Loss: 4.3299, Val Acc: 0.0687
# Epoch 5:  Train Loss: 3.8146, Train Acc: 0.1257,   Val Loss: 4.2622, Val Acc: 0.1069
# Epoch 6:  Train Loss: 3.4754, Train Acc: 0.1675,   Val Loss: 4.1715, Val Acc: 0.0840
# Epoch 7:  Train Loss: 3.1645, Train Acc: 0.2251,   Val Loss: 4.0540, Val Acc: 0.1069
# Epoch 8:  Train Loss: 2.6757, Train Acc: 0.3700,   Val Loss: 4.0187, Val Acc: 0.1069
# Epoch 9:  Train Loss: 2.2533, Train Acc: 0.4677,   Val Loss: 4.2056, Val Acc: 0.1221
# Epoch 10:  Train Loss: 1.8635, Train Acc: 0.5759,   Val Loss: 4.3893, Val Acc: 0.0916
# Epoch 11:  Train Loss: 1.5617, Train Acc: 0.6667,   Val Loss: 4.1087, Val Acc: 0.1679
# ...

# %%
import matplotlib.pyplot as plt
 
# Plot loss
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
 
# Plot accuracy
plt.figure(figsize=(10, 5))
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.title('Accuracy vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
test_accuracy2 = evaluate_model(model2, test_loader2)*100
print(f"Test accuracy: {test_accuracy2:.4f}%")
# Out:
# Test accuracy: 12.0000%
