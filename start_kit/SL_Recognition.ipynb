# %% [markdown]
# # Project Overview
#
# ### 1.1 Introduction
# Sign language recognition is crucial for enhancing communication for those who rely on sign language. It enables smoother interactions in various settings, including education, healthcare, and everyday social situations. By automating the translation of sign language into spoken or written language, we can empower individuals with hearing impairments, improve their access to information and services, and promote greater understanding among the general population. Furthermore, advancements in this field could lead to the development of assistive technologies that integrate seamlessly into daily life, enhancing overall quality of life for users.
#
# ### 1.2 Importance of Sign Language Recognition
# The significance of sign language recognition lies in its potential to enhance communication for individuals who depend on sign language. It facilitates smoother interactions across various sectors, such as education, healthcare, and daily social settings. By automating the translation of sign language into spoken or written language, we can empower those with hearing impairments, improve their access to vital information and services, and foster greater understanding within society. Additionally, advancements in this field could pave the way for the creation of assistive technologies that seamlessly integrate into daily life, further enhancing the quality of life for users.
#
# --------

# %% [markdown]
# # About the Dataset
#
# ### 2.1 Description of WLASL100
# The WLASL100 dataset is a subset of the larger WLASL (Word-level American Sign Language) dataset, specifically designed for sign language recognition tasks. This sub-dataset consists of 100 distinct classes, each representing a specific sign in American Sign Language (ASL). The dataset comprises video recordings that capture the dynamic movements and expressions associated with each sign, providing a rich resource for training and evaluating deep learning models in the domain of sign language recognition.
#
# ### 2.2 Data Characteristics
# The WLASL100 dataset is characterized by its diverse range of signs, encompassing various linguistic features of ASL. Each class is represented by multiple video instances and signed by different signers, allowing the model to learn from variations in signing styles, contexts, and individual differences. The data is carefully curated to ensure it includes a wide array of signs, thereby enhancing the model's ability to generalize across different users and signing scenarios.
#
# --------

# %% [markdown]
# # Structure of the Model
#
# ### 3.1 Overview of the Pipeline
# The project pipeline consists of multiple phases. To begin with, we started with data acquisition and preprocessing. This includes downloading the videos and organizing them, data splitting, and frames extraction. This is followed by features extraction & model development and training, which is based on ResNet & BiLSTM. Lastly, model evaluation and reporting to analyze the results.
#
# ### 3.2 Data Collection
# In order to download the WLASL-100 subset dataset, we made a script to go through the first 100 classes and download video instances. However, further organization had to be done to split the videos into training, validation, and testing datasets.
#
# ### 3.3 Data Preprocessing
# We started by fetching the labels and creating a dictionary to rename each video instance with its corresponding label, as they were only named by their video ID. Similarly, we renamed video instances with their labels. This makes it easier to load the video info in one fetch later on. Next, we extracted frames for each video instance to either downsample or upsample based on the current and target FPS.
#
# ### 3.4 Model Selection
# The model is based on a ResNet50 + BiLSTM architecture. Starting by extracting the abstract features that represent spatial information from each frame, which would be fed into BiLSTM later on in the model training. In addition, we chose Adam as the optimizer and cross entropy as a loss function.
#
# --------

# %% [markdown]
# # Part1: Data handling

# %%
import json
import os
import shutil
import torch
import torchvision.models as models
import torch.nn as nn
import torchvision.transforms as transforms
import numpy as np

# %%
json_file_path = 'WLASL_100.json'

# %% [markdown]
# #### Loading video information

# %%
def load_video_info(json_file):
    """Loads video information such as FPS, frame range, and split from a JSON file."""
    try:
        # Attempt to open and read the JSON file
        with open(json_file, 'r') as f:
            data = json.load(f)
    except FileNotFoundError:
        # Handle case where the file does not exist
        print(f"Error: JSON file '{json_file}' not found.")
        return None
    except json.JSONDecodeError:
        # Handle case where the JSON is improperly formatted
        print(f"Error: Invalid JSON format in '{json_file}'.")
        return None

    video_info = {}
    for item in data:
        # 'gloss' represents the class or label associated with the video
        gloss = item["gloss"]
        for instance in item["instances"]:
            # Extract key details about each video instance
            video_id = instance["video_id"]
            fps = instance["fps"]  # Frames per second
            frame_start = instance["frame_start"]  # Starting frame
            frame_end = instance["frame_end"]  # Ending frame (or -1 for the entire video)
            split = instance["split"]  # Data split (e.g., train, val, test)
            instance_id = instance["instance_id"]  # Identifier for this instance of the gloss

            # Store video details if not already recorded
            if video_id not in video_info:
                video_info[video_id] = {
                    "gloss": gloss, 
                    "fps": fps, 
                    "frame_start": frame_start, 
                    "frame_end": frame_end,  
                    "split": split, 
                    "instance_id": instance_id  
                }
    return video_info

# %%
# this variable contain the {gloss, fps, frame_start, frame_end, split} information for each instance
video_info = load_video_info(json_file_path)

# %%
print(video_info)
# Out:
# {'69241': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 0}, '65225': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 1}, '68011': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 2}, '68208': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': 60, 'split': 'train', 'instance_id': 3}, '68012': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 4}, '70212': {'gloss': 'book', 'fps': 25, 'frame_start': 2150, 'frame_end': 2249, 'split': 'val', 'instance_id': 5}, '70266': {'gloss': 'book', 'fps': 25, 'frame_start': 3732, 'frame_end': 3852, 'split': 'train', 'instance_id': 6}, '07085': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 7}, '07086': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 8},
# ...

# %% [markdown]
# #### Video Renaming

# %%
# Paths to the JSON file and the folder containing the original video files
json_file_path = 'WLASL_100.json'  
video_folder_path = 'raw_videos_mp4'  

# Load the JSON data containing video metadata
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Iterate through each gloss (label) entry in the dataset
for gloss_entry in data:
    gloss = gloss_entry["gloss"]  # Class or label of the video
    for instance in gloss_entry["instances"]:
        video_id = instance["video_id"]  # Unique identifier for the video
        instance_id = instance["instance_id"]  # Instance ID for this specific video

        # Generate old and new filenames
        old_file_name = f"{video_id}.mp4"  
        new_file_name = f"{gloss}_{video_id}_{instance_id}.mp4"  

        # Construct the full paths for renaming
        old_file_path = os.path.join(video_folder_path, old_file_name)
        new_file_path = os.path.join(video_folder_path, new_file_name)

        # Rename the file if it exists, otherwise print a warning
        if os.path.exists(old_file_path):
            os.rename(old_file_path, new_file_path)  # Rename the file
            print(f"Renamed: {old_file_name} -> {new_file_name}")
        else:
            print(f"File not found: {old_file_name}")  # Warn if the file is missing
# Out:
# File not found: 69241.mp4
# File not found: 65225.mp4
# File not found: 68011.mp4
# File not found: 68208.mp4
# File not found: 68012.mp4
# File not found: 70212.mp4
# File not found: 70266.mp4
# File not found: 07085.mp4
# File not found: 07086.mp4
# File not found: 07087.mp4
# File not found: 07069.mp4
# File not found: 07088.mp4
# File not found: 07089.mp4
# File not found: 07090.mp4
# File not found: 07091.mp4
# File not found: 07092.mp4
# File not found: 07093.mp4
# File not found: 07068.mp4
# File not found: 07094.mp4
# File not found: 07095.mp4
# File not found: 07096.mp4
# File not found: 07097.mp4
# File not found: 07070.mp4
# File not found: 07098.mp4
# File not found: 07099.mp4
# File not found: 07071.mp4
# File not found: 07072.mp4
# File not found: 07073.mp4
# File not found: 67424.mp4
# File not found: 07074.mp4
# File not found: 07075.mp4
# File not found: 07076.mp4
# File not found: 07077.mp4
# File not found: 07078.mp4
# File not found: 07079.mp4
# ...

# %% [markdown]
# #### Data Splitting

# %%
from sklearn.model_selection import train_test_split

# Paths
video_folder_path = 'raw_videos_mp4'  
output_folder_path = 'video_data'  

# Create directories for split data
train_folder = os.path.join(output_folder_path, 'train_data')
val_folder = os.path.join(output_folder_path, 'val_data')
test_folder = os.path.join(output_folder_path, 'test_data')

os.makedirs(train_folder, exist_ok=True)  # Create train folder if it doesn't exist
os.makedirs(val_folder, exist_ok=True)   # Create validation folder if it doesn't exist
os.makedirs(test_folder, exist_ok=True)  # Create test folder if it doesn't exist

# Prepare a dictionary to group video file paths by gloss (class/label)
gloss_videos = {}

# Group videos by gloss using the filename pattern
for filename in os.listdir(video_folder_path):
    if filename.endswith(".mp4"):  # Check if the file is a video

        # Extract the gloss (label) from the filename (format used: gloss_videoID_instanceID.mp4)
        gloss = filename.split('_')[0]
        video_path = os.path.join(video_folder_path, filename)

        # Initialize the list for the gloss if not already created
        if gloss not in gloss_videos:
            gloss_videos[gloss] = []
        gloss_videos[gloss].append(video_path)  # Add the video path to the gloss's list

# Split and move videos into train, validation, and test sets
for gloss, videos in gloss_videos.items():
    if videos: 
        
        # Split videos into training (60%) and temporary (40%) sets
        train_videos, test_videos = train_test_split(videos, test_size=0.4, random_state=42)
        
        # Further split the temporary set into validation (20%) and test (20%) sets
        val_videos, test_videos = train_test_split(test_videos, test_size=0.5, random_state=42)

        # Move training videos to the train folder
        for video in train_videos:
            shutil.copy(video, os.path.join(train_folder, os.path.basename(video)))

        # Move validation videos to the val folder
        for video in val_videos:
            shutil.copy(video, os.path.join(val_folder, os.path.basename(video)))

        # Move test videos to the test folder
        for video in test_videos:
            shutil.copy(video, os.path.join(test_folder, os.path.basename(video)))

print(f"Videos have been split and saved to {output_folder_path}")

# %% [markdown]
# ### Validating videos namings

# %%
# check if all classes are present in all folders
def check_classes(data_folder):
    classes = set()
    for filename in os.listdir(data_folder):
        if filename.endswith(".mp4"):
            class_name = filename.split("_")[0]
            classes.add(class_name)
    return classes

# %%
trainLabels = check_classes("video_data/test_data") 
print(trainLabels)
print(len(trainLabels))
# Out:
# {'basketball', 'blue', 'birthday', 'cook', 'give', 'cow', 'accident', 'bowling', 'no', 'like', 'work', 'meet', 'fine', 'later', 'tall', 'letter', 'study', 'tell', 'walk', 'man', 'short', 'black', 'cousin', 'son', 'fish', 'secretary', 'table', 'year', 'who', 'now', 'language', 'full', 'decide', 'right', 'dog', 'paper', 'but', 'chair', 'change', 'hot', 'forget', 'color', 'apple', 'computer', 'cool', 'play', 'cheat', 'white', 'go', 'medicine', 'mother', 'clothes', 'corn', 'want', 'need', 'woman', 'pink', 'deaf', 'many', 'drink', 'family', 'thursday', 'bed', 'candy', 'finish', 'book', 'wrong', 'orange', 'yes', 'shirt', 'what', 'paint', 'enjoy', 'brown', 'dark', 'kiss', 'last', 'doctor', 'city', 'time', 'graduate', 'hearing', 'pizza', 'thanksgiving', 'eat', 'jacket', 'africa', 'thin', 'same', 'bird', 'purple', 'before', 'help', 'dance', 'hat', 'pull', 'can', 'school', 'how', 'all'}
# 100

# %%
valLabels = check_classes("video_data/val_data")
print(valLabels)
print(len(valLabels))
# Out:
# {'basketball', 'blue', 'birthday', 'cook', 'give', 'cow', 'accident', 'bowling', 'no', 'like', 'work', 'meet', 'fine', 'later', 'tall', 'letter', 'study', 'tell', 'walk', 'man', 'short', 'black', 'cousin', 'son', 'fish', 'secretary', 'table', 'year', 'who', 'now', 'language', 'full', 'decide', 'right', 'dog', 'paper', 'but', 'chair', 'change', 'hot', 'forget', 'color', 'apple', 'computer', 'cool', 'play', 'cheat', 'white', 'go', 'medicine', 'mother', 'clothes', 'corn', 'want', 'need', 'woman', 'pink', 'deaf', 'many', 'drink', 'family', 'thursday', 'bed', 'candy', 'finish', 'book', 'wrong', 'orange', 'yes', 'shirt', 'what', 'paint', 'enjoy', 'brown', 'dark', 'kiss', 'last', 'doctor', 'city', 'time', 'graduate', 'hearing', 'pizza', 'thanksgiving', 'eat', 'jacket', 'africa', 'thin', 'same', 'bird', 'purple', 'before', 'help', 'dance', 'hat', 'pull', 'can', 'school', 'how', 'all'}
# 100

# %%
testLabels = check_classes("video_data/test_data")
print(testLabels)
print(len(testLabels))
# Out:
# {'basketball', 'blue', 'birthday', 'cook', 'give', 'cow', 'accident', 'bowling', 'no', 'like', 'work', 'meet', 'fine', 'later', 'tall', 'letter', 'study', 'tell', 'walk', 'man', 'short', 'black', 'cousin', 'son', 'fish', 'secretary', 'table', 'year', 'who', 'now', 'language', 'full', 'decide', 'right', 'dog', 'paper', 'but', 'chair', 'change', 'hot', 'forget', 'color', 'apple', 'computer', 'cool', 'play', 'cheat', 'white', 'go', 'medicine', 'mother', 'clothes', 'corn', 'want', 'need', 'woman', 'pink', 'deaf', 'many', 'drink', 'family', 'thursday', 'bed', 'candy', 'finish', 'book', 'wrong', 'orange', 'yes', 'shirt', 'what', 'paint', 'enjoy', 'brown', 'dark', 'kiss', 'last', 'doctor', 'city', 'time', 'graduate', 'hearing', 'pizza', 'thanksgiving', 'eat', 'jacket', 'africa', 'thin', 'same', 'bird', 'purple', 'before', 'help', 'dance', 'hat', 'pull', 'can', 'school', 'how', 'all'}
# 100

# %% [markdown]
# #### Loading Video Metadata

# %%
# Function to prepare metadata for a specific subset (train, val, or test)
def prepare_metadata_for_folder(json_file_path, data_dir, subset_folder):
    """
    Prepares metadata for video files within a specified subset folder.

    Args:
        json_file_path (str): Path to the JSON file containing dataset annotations.
        data_dir (str): Path to the directory containing subset folders.
        subset_folder (str): Name of the subset folder (e.g., 'train_data', 'val_data', 'test_data').

    Returns:
        dict: Metadata for videos in the specified subset folder, keyed by video ID.
    """
    # Load dataset annotations from the JSON file
    with open(json_file_path, 'r') as f:
        data = json.load(f)

    subset_info = {}  # Dictionary to store metadata for the subset
    target_path = os.path.join(data_dir, subset_folder)  # Path to the specific subset folder

    # Iterate over each gloss (class) in the dataset
    for item in data:
        gloss = item['gloss']  # The gloss (label) for the video
        for instance in item['instances']:  
            video_id = instance['video_id'] 
            fps = instance.get('fps', 25)  
            frame_start = instance.get('frame_start', 0) 
            frame_end = instance.get('frame_end', -1)  
            instance_id = instance['instance_id']  

            # Construct the video filename based on its metadata
            video_filename = f"{gloss}_{video_id}_{instance_id}.mp4"
            video_path = os.path.join(target_path, video_filename)  # Full path to the video file

            # Check if the video exists in the specified subset folder
            if os.path.exists(video_path):
                # If the video exists, store its metadata in the subset dictionary
                subset_info[video_id] = {
                    'gloss': gloss,
                    'fps': fps,
                    'frame_start': frame_start,
                    'frame_end': frame_end,
                    'instance_id': instance_id
                }

    return subset_info  # Return the metadata dictionary for the subset

# %%
train_info = prepare_metadata_for_folder('WLASL_100.json', 'video_data', 'train_data')
val_info = prepare_metadata_for_folder('WLASL_100.json', 'video_data', 'val_data')
test_info = prepare_metadata_for_folder('WLASL_100.json', 'video_data', 'test_data')

# %% [markdown]
# #### Frame extraction

# %%
# Libraries of the section
import cv2

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
def extract_frames(video_path, fps, frame_start, frame_end):
    """
    Extracts frames from a video file within a specified frame range.

    Args:
        video_path (str): Path to the video file.
        fps (int): Frames per second of the video (not directly used here but for consistency).
        frame_start (int): The starting frame index to extract.
        frame_end (int): The ending frame index to extract (-1 means extract till the end).

    Returns:
        list: A list of extracted frames as numpy arrays.

    Notes:
        - Handles cases where `frame_end` is -1, indicating no specific end frame.
        - Skips frames before `frame_start` and stops once `frame_end` is reached.
    """
    cap = cv2.VideoCapture(video_path)
    frames = []
    current_frame = 0

    if not cap.isOpened():
        print(f"Error: Could not open video file {video_path}")
        return []

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        if current_frame >= frame_start:
            frames.append(frame)
            if frame_end != -1 and current_frame >= frame_end:
                break  # Stop if frame_end is specified and reached

        current_frame += 1

    cap.release()
    return frames

# %%
def downsample_or_upsample_frames(frames, current_fps, target_fps):
    """
    Adjusts the frame rate of a list of frames to match the target FPS.

    Args:
        frames (list): List of video frames (numpy arrays).
        current_fps (int): Current frames per second of the video.
        target_fps (int): Desired frames per second.

    Returns:
        list: A list of frames adjusted to the target FPS.

    Notes:
        - If `current_fps` < `target_fps`, frames are repeated to increase the rate.
        - If `current_fps` > `target_fps`, frames are skipped to decrease the rate.
        - If `current_fps` == `target_fps`, frames are returned as-is.
    """
    if current_fps == target_fps:
        return frames

    if current_fps < target_fps:
        # Upsample: Repeat frames to increase frame rate
        factor = target_fps // current_fps
        new_frames = []
        for frame in frames:
            new_frames.extend([frame] * factor)
        return new_frames
    else:
        # Downsample: Skip frames to decrease frame rate
        factor = current_fps // target_fps
        return frames[::factor]

# %%
def create_sequences(frames, sequence_length):
    """
    Creates sequences of frames from a list of frames for time-series processing.

    Args:
        frames (list): List of video frames (numpy arrays).
        sequence_length (int): Length of each frame sequence.

    Returns:
        list: A list of frame sequences, where each sequence is a list of frames.

    Notes:
        - Returns an empty list if there aren't enough frames to create even one sequence.
        - Sliding window approach: Moves one frame at a time to create overlapping sequences.
    """
    if len(frames) < sequence_length:
        return []  # Return empty list if not enough frames
    sequences = []
    for i in range(len(frames) - sequence_length + 1):
        sequence = frames[i:i + sequence_length]
        sequences.append(sequence)
    return sequences

# %% [markdown]
# #### Features Extraction

# %%
# Libraries of th section

import torch
import torchvision.models as models
import torch.nn as nn
import torchvision.transforms as transforms

# %%
def extract_resnet_features_batch(frames, resnet_model, transform, device, batch_size=32):
    """
    Extracts ResNet features for a batch of video frames.

    Args:
        frames (list): List of video frames (as numpy arrays).
        resnet_model (torch.nn.Module): Pre-trained ResNet model.
        transform (torchvision.transforms.Compose): Transformations to preprocess frames.
        device (torch.device): Device to perform computation (CPU or GPU).
        batch_size (int): Number of frames to process in a batch.

    Returns:
        list: 2048-dimensional ResNet features for all frames.

    Notes:
        - Frames are transformed and processed in batches for efficiency.
        - Outputs are flattened to 1D vectors of size 2048.
        - Any remaining frames not fitting in a full batch are processed separately.
    """
    features = []
    batch = []

    for frame in frames:
        img_tensor = transform(frame)  # Apply transformations to preprocess the frame
        batch.append(img_tensor)

        if len(batch) == batch_size:
            batch_tensor = torch.stack(batch).to(device)  # Stack frames into a batch tensor and move to GPU
            with torch.no_grad():
                outputs = resnet_model(batch_tensor)  # Forward pass through ResNet
                outputs = outputs.view(outputs.size(0), -1)  # Flatten to (batch_size, 2048)
            features.extend(outputs.cpu().numpy())  # Collect features and move them back to CPU
            batch = []  # Reset batch

    # Process any remaining frames
    if batch:
        batch_tensor = torch.stack(batch).to(device)
        with torch.no_grad():
            outputs = resnet_model(batch_tensor)
            outputs = outputs.view(outputs.size(0), -1)
        features.extend(outputs.cpu().numpy())

    return features

# %%
def preprocess_and_extract_features(data_dir, split_info, split_type, resnet_model, transform, device, sequence_length=32, target_fps=25, batch_size=32):
    """
    Preprocesses videos, extracts frames, and computes features for a dataset split.

    Args:
        data_dir (str): Base directory containing video files.
        split_info (dict): Metadata about the videos in the split.
        split_type (str): Type of split ('train', 'val', 'test').
        resnet_model (torch.nn.Module): Pre-trained ResNet model for feature extraction.
        transform (torchvision.transforms.Compose): Transformations to preprocess frames.
        device (torch.device): Device to perform computation (CPU or GPU).
        sequence_length (int): Number of frames per sequence.
        target_fps (int): Target frames per second for uniform frame rate.
        batch_size (int): Batch size for ResNet processing.

    Returns:
        (features, labels)
            - features (list): Extracted ResNet features for all sequences.
            - labels (list): Corresponding labels for the sequences.

    Notes:
        - Videos are preprocessed by extracting and resampling frames.
        - Sequences are generated by splitting the frames into chunks of `sequence_length`.
        - ResNet extracts features for each sequence.
        - Skips incomplete sequences with fewer than `sequence_length` frames.
    """
    features = []
    labels = []

    split_folder = os.path.join(data_dir, f"{split_type}_data")  # Path to the specific data split folder
    
    for video_id, info in split_info.items():
        video_filename = f"{info['gloss']}_{video_id}_{info['instance_id']}.mp4"
        video_path = os.path.join(split_folder, video_filename)
        
        if os.path.exists(video_path):
            # Extract frames from the video
            frames = extract_frames(video_path, info['fps'], info['frame_start'], info['frame_end'])
            if not frames:
                print(f"No frames extracted from {video_path}. Skipping.")
                continue

            # Adjust frames to target FPS
            frames = downsample_or_upsample_frames(frames, info['fps'], target_fps)

            # Create sequences of specified length
            sequences = create_sequences(frames, sequence_length)
            
            for sequence in sequences:
                if len(sequence) < sequence_length:
                    continue  # Skip incomplete sequences

                # Extract ResNet features for the sequence
                features_seq = extract_resnet_features_batch(sequence, resnet_model, transform, device, batch_size)
                features.append(features_seq)
                labels.append(info['gloss'])
        else:
            print(f"Warning: Video file '{video_path}' not found.")

    return features, labels

# %% [markdown]
# ### Choice of pre-trained model

# %%
# Load ResNet50 and modify
resnet_model = models.resnet50(pretrained=True)
# Remove the last fully connected layer to use ResNet as a feature extractor
resnet_model = nn.Sequential(*list(resnet_model.children())[:-1])
# Move the model to the device (GPU or CPU) for computation
resnet_model.to(device)
# Set the model to evaluation mode to disable dropout and batch normalization updates
resnet_model.eval()


# Define transformations for preprocessing video frames
transform = transforms.Compose([
    transforms.ToPILImage(),                # Convert frames from NumPy arrays to PIL images for easier manipulation
    transforms.Resize((224, 224)),          # Resize frames to 224x224 pixels, the input size for ResNet
    transforms.ToTensor(),                  # Convert images to PyTorch tensors
    transforms.Normalize(                   # Normalize the tensor values to match the ResNet pretraining distribution
        mean=[0.485, 0.456, 0.406],         # Mean values for each channel (RGB)
        std=[0.229, 0.224, 0.225]           # Standard deviations for each channel (RGB)
    )
])
# Out:
# C:\Users\Hayder\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Hayder\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
data_dir = 'video_data'

# %% [markdown]
# ### Extracting video features from the subsets folders

# %%
# Extract features and labels for the training set
train_features, train_labels = preprocess_and_extract_features(
    data_dir, train_info, 'train', resnet_model, transform, device,
    sequence_length=16, target_fps=25, batch_size=32
)

# %%
# Extract features and labels for the validation set
val_features, val_labels = preprocess_and_extract_features(
    data_dir, val_info, 'val', resnet_model, transform, device,
    sequence_length=16, target_fps=25, batch_size=32
)

# %%
# Extract features and labels for the test set
test_features, test_labels = preprocess_and_extract_features(
    data_dir, test_info, 'test', resnet_model, transform, device,
    sequence_length=16, target_fps=25, batch_size=32
)

# %%
unique_classes = np.load('features_labels/unique_classes.npy', allow_pickle=True)
unique_classes = list(unique_classes[0])

# %% [markdown]
# #### Labels Encoding

# %%
# Libraries of the section
from torch.utils.data import Dataset
import torchvision.transforms as transforms
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import LabelEncoder

# %%
batch_size = 32 # Adjust based on your system's capacity

# %%
label_encoder = LabelEncoder()

label_encoder.fit(unique_classes)
# Out:
# LabelEncoder()

# %%
train_encoded_labels = label_encoder.transform(train_labels)

# Convert to tensors
features_tensor = torch.tensor(train_features, dtype=torch.float32)
labels_tensor = torch.tensor(train_encoded_labels, dtype=torch.long)

# Create a TensorDataset and DataLoader
train_dataset = TensorDataset(features_tensor, labels_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
# Out:
# C:\Users\Hayder\AppData\Local\Temp\ipykernel_22332\2725627781.py:4: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:281.)
#   features_tensor = torch.tensor(train_features, dtype=torch.float32)

# %%
val_encoded_labels = label_encoder.transform(val_labels)

# Convert to tensors
val_features_tensor = torch.tensor(val_features, dtype=torch.float32)
val_labels_tensor = torch.tensor(val_encoded_labels, dtype=torch.long)

# Create a TensorDataset and DataLoader
val_dataset = TensorDataset(val_features_tensor, val_labels_tensor)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
test_encoded_labels = label_encoder.transform(test_labels)

# Convert to tensors
test_features_tensor = torch.tensor(test_features, dtype=torch.float32)
test_labels_tensor = torch.tensor(test_encoded_labels, dtype=torch.long)

# Create a TensorDataset and DataLoader
test_dataset = TensorDataset(test_features_tensor, test_labels_tensor)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ### BiLSTM Model Definition

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class SignLanguageLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes, num_layers=1, dropout=0.5):
        """
        Initializes the SignLanguageLSTM model with a bidirectional LSTM,
        fully connected layers, and dropout to classify sequences.
        
        Args:
            input_size (int): The size of the input features (e.g., 2048 from ResNet).
            hidden_size (int): Number of units in the hidden layer of the LSTM.
            num_classes (int): Number of classes for the output classification.
            num_layers (int): Number of LSTM layers. Default is 1.
            dropout (float): Dropout rate to prevent overfitting. Default is 0.5.
        """
        super(SignLanguageLSTM, self).__init__()

        # Bidirectional LSTM layer to process sequences in both forward and backward directions
        self.lstm = nn.LSTM(
            input_size, hidden_size, num_layers,
            batch_first=True, bidirectional=True
        )

        # Layer normalization to stabilize the outputs of the LSTM
        self.layer_norm = nn.LayerNorm(hidden_size * 2)

        # Fully connected layers to reduce the dimensionality and classify the sequences
        self.fc1 = nn.Linear(hidden_size * 2, 256)  # First layer reduces to 256 dimensions
        self.fc2 = nn.Linear(256, 128)             # Second layer reduces to 128 dimensions
        self.fc3 = nn.Linear(128, num_classes)     # Final layer maps to the number of classes

        # Dropout to reduce overfitting
        self.dropout = nn.Dropout(dropout)

        # Initialize weights for all layers
        self.init_weights()

    def forward(self, x):
        """
        Defines the forward pass of the model.
        
        Args:
            x (torch.Tensor): Input tensor of shape (batch_size, sequence_length, input_size).
        
        Returns:
            torch.Tensor: Output tensor of shape (batch_size, num_classes).
        """
        # Pass the input through the LSTM
        lstm_out, _ = self.lstm(x)

        # Apply LayerNorm to the LSTM output
        lstm_out = self.layer_norm(lstm_out)

        # Mean pooling to summarize information across time steps
        out = torch.mean(lstm_out, dim=1)

        # Apply dropout for regularization
        out = self.dropout(out)

        # Pass through fully connected layers with ReLU activation
        out = F.relu(self.fc1(out))
        out = self.dropout(out)  # Apply dropout after the first layer
        out = F.relu(self.fc2(out))
        out = self.fc3(out)      # Final layer produces raw logits

        return out

    def init_weights(self):
        """
        Initializes the weights of the model for better convergence during training.
        """
        for m in self.modules():
            if isinstance(m, nn.Linear):
                # Xavier initialization for weights and zeros for biases in linear layers
                nn.init.xavier_uniform_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.LSTM):
                # Xavier initialization for LSTM weights and zeros for biases
                for name, param in m.named_parameters():
                    if 'weight' in name:
                        nn.init.xavier_uniform_(param)
                    elif 'bias' in name:
                        nn.init.zeros_(param)

# %% [markdown]
# #### Training loop

# %%
def train_and_evaluate_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=20, patience=5, use_early_stopping=True):
    """Train and evaluate a model with optional early stopping."""
    
    # Set device (GPU or CPU)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    # Initialize variables for early stopping and tracking metrics
    best_val_loss = float('inf')
    epochs_without_improvement = 0
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        running_loss = 0.0
        correct_predictions = 0
        total_predictions = 0

        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            # Accumulate metrics
            running_loss += loss.item() * features.size(0)
            _, predicted = torch.max(outputs, 1)
            correct_predictions += (predicted == labels).sum().item()
            total_predictions += labels.size(0)

        # Compute average loss and accuracy for training
        epoch_loss = running_loss / total_predictions
        epoch_accuracy = correct_predictions / total_predictions
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_accuracy)

        # Validation phase
        model.eval()
        val_running_loss = 0.0
        val_correct_predictions = 0
        val_total_predictions = 0

        with torch.no_grad():
            for val_features, vali_labels in val_loader:
                val_features, vali_labels = val_features.to(device), vali_labels.to(device)
                val_outputs = model(val_features)
                val_loss = criterion(val_outputs, vali_labels)
                
                # Accumulate validation metrics
                val_running_loss += val_loss.item() * val_features.size(0)
                _, val_predicted = torch.max(val_outputs, 1)
                val_correct_predictions += (val_predicted == vali_labels).sum().item()
                val_total_predictions += vali_labels.size(0)

        # Compute average loss and accuracy for validation
        val_epoch_loss = val_running_loss / val_total_predictions
        val_epoch_accuracy = val_correct_predictions / val_total_predictions
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_accuracy)


        # Print progress
        print(f"Epoch [{epoch + 1}/{num_epochs}], "
              f"Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_accuracy:.4f}, "
              f"Val Loss: {val_epoch_loss:.4f}, Val Accuracy: {val_epoch_accuracy:.4f}")

        # Early stopping logic
        if use_early_stopping:
            min_delta = 0.1  # Minimum improvement to consider as better
            if val_epoch_loss < (best_val_loss - min_delta):
                best_val_loss = val_epoch_loss
                epochs_without_improvement = 0
                torch.save(model.state_dict(), 'best_model.pth')
            else:
                epochs_without_improvement += 1
                if epochs_without_improvement >= patience:
                    print("Early stopping triggered. Stopping training.")
                    break

    return train_losses, val_losses, train_accuracies, val_accuracies

# %% [markdown]
# ### Hyperparameters of the model & Model Initialization

# %%
# Input size corresponds to the feature size of ResNet output (2048).
input_size = 2048  # This matches the feature size from your ResNet.

# Hidden size determines the size of the hidden state in the LSTM.
hidden_size = 512  # {256, 512}.

# Number of output classes; matches the unique labels in your dataset.
num_classes = 100  # Number of unique classes.

# Number of LSTM layers.
num_layers = 3  # {2, 3}.

# Dropout rate for regularization to prevent overfitting.
dropout = 0.5  # {0.2, 0.3, 0.4, 0.5}.

# Initialize the LSTM model for sign language recognition.
model = SignLanguageLSTM(input_size, hidden_size, num_classes, num_layers, dropout)

# Using CrossEntropyLoss with label smoothing to handle class imbalance and soften hard class boundaries.
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)

# Optimizer is Adam with a learning rate of 1e-4 and weight decay for regularization.
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-3)

# %%
train_losses, val_losses, train_accuracies, val_accuracies = train_and_evaluate_model(
    model,                   # The initialized model.
    train_loader,            # DataLoader for the training set.
    val_loader,              # DataLoader for the validation set.
    criterion,               # Loss function.
    optimizer,               # Optimizer.
    num_epochs=20,           # Number of epochs to train.
    patience=3,              # Early stopping patience.
    use_early_stopping=True  # Enable early stopping.
)
# Out:
# Epoch [1/20], Train Loss: 4.6098, Train Accuracy: 0.0144, Val Loss: 4.5712, Val Accuracy: 0.0303
# Epoch [2/20], Train Loss: 4.4442, Train Accuracy: 0.0416, Val Loss: 4.2658, Val Accuracy: 0.0834
# Epoch [3/20], Train Loss: 3.9917, Train Accuracy: 0.1222, Val Loss: 3.7288, Val Accuracy: 0.2201
# Epoch [4/20], Train Loss: 3.2483, Train Accuracy: 0.2878, Val Loss: 3.0858, Val Accuracy: 0.4153
# Epoch [5/20], Train Loss: 2.4865, Train Accuracy: 0.5029, Val Loss: 2.5875, Val Accuracy: 0.6086
# Epoch [6/20], Train Loss: 1.9189, Train Accuracy: 0.6872, Val Loss: 2.3514, Val Accuracy: 0.6971
# Epoch [7/20], Train Loss: 1.5760, Train Accuracy: 0.8108, Val Loss: 2.2632, Val Accuracy: 0.7269
# Epoch [8/20], Train Loss: 1.3834, Train Accuracy: 0.8769, Val Loss: 2.1954, Val Accuracy: 0.7361
# Epoch [9/20], Train Loss: 1.2597, Train Accuracy: 0.9177, Val Loss: 2.1023, Val Accuracy: 0.7580
# Epoch [10/20], Train Loss: 1.1839, Train Accuracy: 0.9378, Val Loss: 2.0852, Val Accuracy: 0.7671
# ...

# %% [markdown]
# #### Plots

# %%
import matplotlib.pyplot as plt
 
# Plot loss
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
 
# Plot accuracy
plt.figure(figsize=(10, 5))
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.title('Accuracy vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Testing the model

# %%
def evaluate_model(model, loader):
    # Set the model to evaluation mode
    model.eval()
    
    # Variables to track the number of correct predictions and total samples
    correct = 0
    total = 0
    
    # Determine the device (GPU or CPU)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # Disable gradient computation since it's not needed during evaluation
    with torch.no_grad():
        for inputs, labels in loader:
            # Move data and labels to the appropriate device
            inputs, labels = inputs.to(device), labels.to(device)
            
            # Forward pass: Compute predictions
            outputs = model(inputs)
            
            # Get the predicted class (class with the highest probability)
            _, preds = torch.max(outputs, 1)
            
            # Update the count of correct predictions
            correct += (preds == labels).sum().item()
            
            # Update the total number of samples
            total += labels.size(0)
    
    # Compute the overall accuracy as a ratio of correct predictions to total samples
    accuracy = correct / total
    
    return accuracy

# %%
test_accuracy = evaluate_model(model, test_loader)*100
print(f"Test accuracy: {test_accuracy:.4f}%")
# Out:
# Test accuracy: 75.3537%

# %% [markdown]
# ### Error analysis

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix

# Modifying the settings to show the entire DataFrame when using the "display" function
pd.set_option('display.max_rows', None)

model.eval()
all_preds = []
all_targets = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_targets.extend(labels.cpu().numpy())

# Compute confusion matrix
cm = confusion_matrix(all_targets, all_preds)

classes = label_encoder.classes_
num_classes = len(classes)
rows = []

for i, cls in enumerate(classes):
    row = cm[i]
    # Sort indices by descending count
    sorted_indices = np.argsort(row)[::-1]

    # Collect top 5 misclassifications (excluding the class itself)
    top_5 = []
    for idx in sorted_indices:
        if idx != i:
            top_5.append((classes[idx], int(row[idx])))
        if len(top_5) == 5:
            break

    # Add them to the rows list
    # We'll store rank to know which is top1, top2, etc.
    for rank, (confused_cls, count) in enumerate(top_5, start=1):
        rows.append({
            'Class': cls,
            'Rank': rank,
            'ConfusedWith': confused_cls,
            'Count': count
        })

# Create a single DataFrame after processing all classes
df_misclassifications = pd.DataFrame(rows, columns=['Class', 'Rank', 'ConfusedWith', 'Count'])

# Now pivot the table so each row is a class and we have columns for each of the top 5 confusions
# We can combine 'ConfusedWith' and 'Count' into a single string for easier viewing.
df_misclassifications['ConfusionInfo'] = df_misclassifications['ConfusedWith'] + " (" + df_misclassifications['Count'].astype(str) + ")"

# Pivot to get a wide format: Class as index, Rank as columns, values = ConfusionInfo
df_pivot = df_misclassifications.pivot(index='Class', columns='Rank', values='ConfusionInfo')

# df_pivot will now have each class as a row, and columns 1 through 5 representing the top confusions
# Display the DataFrame
display(df_pivot)
# Out:
# Rank                      1                  2              3               4  \
# Class
# accident          wrong (9)           year (0)        yes (0)       woman (0)
# africa            what (43)      accident (28)      last (22)  secretary (18)
# all               city (37)        change (16)      book (11)        meet (3)
# apple             last (18)          bird (16)  graduate (12)     jacket (11)
# basketball      finish (51)         doctor (4)      paint (3)       apple (2)
# bed               walk (14)  thanksgiving (13)       give (8)      africa (6)
# before            play (12)          last (12)    jacket (10)      school (4)
# bird             brown (48)          cool (43)   birthday (3)      change (1)
# birthday       graduate (3)            yes (0)       year (0)       woman (0)
# black             bird (25)         candy (11)      brown (6)       woman (0)
# blue              candy (1)            yes (0)       year (0)       woman (0)
# ...

# %% [markdown]
# ### Possible Causes of Model Limitations
#
# - Video being too short to extract enough features
# - Loosing many videos due to corrupted mp4 files and not-working video links
# - The computational cost to extract the features and train the model
# - The level of difficulty between [training, validation, testing] samples is not the same
# - The variety of signs for a sample, i.e., signers using different signs for the same word
