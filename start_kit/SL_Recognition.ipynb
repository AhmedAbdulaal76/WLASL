# %% [markdown]
# # Project Overview
#
# ### 1.1 Introduction
# Sign language recognition is crucial for enhancing communication for those who rely on sign language. It enables smoother interactions in various settings, including education, healthcare, and everyday social situations. By automating the translation of sign language into spoken or written language, we can empower individuals with hearing impairments, improve their access to information and services, and promote greater understanding among the general population. Furthermore, advancements in this field could lead to the development of assistive technologies that integrate seamlessly into daily life, enhancing overall quality of life for users.
#
# ### 1.2 Importance of Sign Language Recognition
# The significance of sign language recognition lies in its potential to enhance communication for individuals who depend on sign language. It facilitates smoother interactions across various sectors, such as education, healthcare, and daily social settings. By automating the translation of sign language into spoken or written language, we can empower those with hearing impairments, improve their access to vital information and services, and foster greater understanding within society. Additionally, advancements in this field could pave the way for the creation of assistive technologies that seamlessly integrate into daily life, further enhancing the quality of life for users.
#
# --------

# %% [markdown]
# # About the Dataset
#
# ### 2.1 Description of WLASL100
# The WLASL100 dataset is a subset of the larger WLASL (Word-level American Sign Language) dataset, specifically designed for sign language recognition tasks. This sub-dataset consists of 100 distinct classes, each representing a specific sign in American Sign Language (ASL). The dataset comprises video recordings that capture the dynamic movements and expressions associated with each sign, providing a rich resource for training and evaluating deep learning models in the domain of sign language recognition.
#
# ### 2.2 Data Characteristics
# The WLASL100 dataset is characterized by its diverse range of signs, encompassing various linguistic features of ASL. Each class is represented by multiple video instances and signed by different signers, allowing the model to learn from variations in signing styles, contexts, and individual differences. The data is carefully curated to ensure it includes a wide array of signs, thereby enhancing the model's ability to generalize across different users and signing scenarios.
#
# --------

# %% [markdown]
# # Structure of the Model
#
# ### 3.1 Overview of the Pipeline
# The project pipeline consists of multiple phases. To begin with, we started with data acquisition and preprocessing. This includes downloading the videos and organizing them, data splitting, and frames extraction. This is followed by features extraction & model development and training, which is based on ResNet & LSTM. Lastly, model evaluation and reporting to analyze the results.
#
# ### 3.2 Data Collection
# In order to download the WLASL-100 subset dataset, we made a script to go through the first 100 classes and download video instances. However, further organization had to be done to split the videos into training, validation, and testing datasets.
#
# ### 3.3 Data Preprocessing
# We started by fetching the labels and creating a dictionary to rename each video instance with its corresponding label, as they were only named by their video ID. Similarly, we renamed video instances with their labels. This makes it easier to load the video info in one fetch later on. Next, we extracted frames for each video instance to either downsample or upsample based on the current and target FPS.
#
# ### 3.4 Model Selection
# The model is based on a ResNet50 + LSTM architecture. Starting by extracting the abstract features that represent spatial information from each frame, which would be fed into LSTM later on in the model training. In addition, we chose Adam as the optimizer.
#
# --------

# %% [markdown]
# # Part1: Data handling

# %% [markdown]
# ### Data splitting

# %%
import json
import os
import shutil
import torch
import torchvision.models as models
import torch.nn as nn
import torchvision.transforms as transforms
import numpy as np

# %%
def organize_data(json_file, videos_folder, output_folder):
    """Organizes video data into training, validation, and testing folders based on JSON file."""

    try:
        with open(json_file, 'r') as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"Error: JSON file '{json_file}' not found.")
        return
    except json.JSONDecodeError:
        print(f"Error: Invalid JSON format in '{json_file}'.")
        return

    os.makedirs(os.path.join(output_folder, "train_data"), exist_ok=True)
    os.makedirs(os.path.join(output_folder, "val_data"), exist_ok=True)
    os.makedirs(os.path.join(output_folder, "test_data"), exist_ok=True)

    for entry in data:
        for instance in entry['instances']:
            video_id = instance['video_id']
            video_path = os.path.join(videos_folder, f"{video_id}.mp4")
            split = instance['split']

            if not os.path.exists(video_path):
                print(f"Warning: Video file '{video_path}' not found. Skipping.")
                continue

            if split == "train":
                destination = os.path.join(output_folder, "training_data", f"{video_id}.mp4")
            elif split == "val":
                destination = os.path.join(output_folder, "validation_data", f"{video_id}.mp4")
            elif split == "test":
                destination = os.path.join(output_folder, "testing_data", f"{video_id}.mp4")
            else:
                print(f"Warning: Unknown split '{split}' for video '{video_id}'. Skipping.")
                continue

            try:
                shutil.copy2(video_path, destination)  # copy2 preserves metadata
                print(f"Copied '{video_id}.mp4' to '{split}' folder.")
            except shutil.Error as e:
                print(f"Error copying '{video_id}.mp4': {e}")

def main():
    json_file_path = 'WLASL_100.json'  # Path to your JSON file
    videos_folder_path = 'videos'  # Path to your videos folder
    output_directory = 'organized_data'  # Path to the output directory

    organize_data(json_file_path, videos_folder_path, output_directory)

if __name__ == "__main__":
    main()
# Out:
# Copied '69241.mp4' to 'train' folder.
# ...
# Copied '07069.mp4' to 'train' folder.
# ...
# Copied '07068.mp4' to 'train' folder.
# ...
# Copied '07070.mp4' to 'train' folder.
# ...
# Copied '07074.mp4' to 'train' folder.
# ...
# Copied '69302.mp4' to 'val' folder.
# ...
# Copied '17710.mp4' to 'train' folder.
# ...
# Copied '65540.mp4' to 'train' folder.
# ...
# Copied '17711.mp4' to 'train' folder.
# Copied '17712.mp4' to 'train' folder.
# Copied '17713.mp4' to 'test' folder.
# ...
# Copied '17709.mp4' to 'train' folder.
# ...
# Copied '17720.mp4' to 'train' folder.
# Copied '17721.mp4' to 'train' folder.
# Copied '17722.mp4' to 'train' folder.
# Copied '17723.mp4' to 'train' folder.
# Copied '17724.mp4' to 'val' folder.
# ...
# Copied '12328.mp4' to 'train' folder.
# ...
# Copied '12312.mp4' to 'val' folder.
# ...
# Copied '12311.mp4' to 'train' folder.
# ...
# Copied '12313.mp4' to 'train' folder.
# Copied '12314.mp4' to 'train' folder.
# Copied '12315.mp4' to 'val' folder.
# Copied '12316.mp4' to 'train' folder.
# Copied '12317.mp4' to 'train' folder.
# ...

# %% [markdown]
# ### Data processing

# %% [markdown]
# #### Videos renaming

# %%
def load_labels(json_file):
    """Loads video labels, creating a dictionary with lists of video IDs per gloss."""
    try:
        with open(json_file, 'r') as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"Error: JSON file '{json_file}' not found.")
        return None
    except json.JSONDecodeError:
        print(f"Error: Invalid JSON format in '{json_file}'.")
        return None

    label_data = {}
    for item in data:
        gloss = item["gloss"]
        for instance in item["instances"]:
            video_id = instance["video_id"]
            if gloss not in label_data:
                label_data[gloss] = []
            label_data[gloss].append(video_id)
    return label_data

# %%
def rename_videos(data_dir, video_info):
    """Renames videos using gloss, video_id, and instance_id from video_info."""
    for subfolder in ["train_data", "val_data", "test_data"]:
        subfolder_path = os.path.join(data_dir, subfolder)
        for video_id, info in video_info.items():
            # Check if the video belongs to the current split
            if info['split'] == subfolder.replace('_data', ''):
                filename = f"{video_id}.mp4"
                old_path = os.path.join(subfolder_path, filename)
                if os.path.exists(old_path):
                    new_filename = f"{info['gloss']}_{video_id}_{info['instance_id']}.mp4"
                    new_path = os.path.join(subfolder_path, new_filename)
                    os.rename(old_path, new_path)
                    print(f"Renamed: {old_path} -> {new_path}")
                else:
                    print(f"Warning: Video file '{filename}' not found in '{subfolder_path}'.")

# %%
# constant directory names
json_file_path = 'WLASL_100.json'
# data_dir = 'organized_data'

# %%
def count_unique_classes(folder_path):
    class_names = set()
    for filename in os.listdir(folder_path):
        # Split the filename and get the first part as the class name
        if filename.endswith(".mp4"):
            class_name = filename.split("_")[0]
            class_names.add(class_name)
    
    return len(class_names), class_names

# %%
# Replace 'your_folder_path' with the path to your folder containing the videos
train_folder_path = 'stratified_data/train_data'
train_unique_class_count, train_unique_classes = count_unique_classes(train_folder_path)

print(f"Number of unique training classes: {train_unique_class_count}")
print("Unique classes:", train_unique_classes)
# Out:
# Number of unique training classes: 100
# Unique classes: {'basketball', 'blue', 'birthday', 'cook', 'give', 'cow', 'accident', 'bowling', 'no', 'like', 'work', 'meet', 'fine', 'later', 'tall', 'letter', 'study', 'tell', 'walk', 'man', 'short', 'black', 'cousin', 'son', 'fish', 'secretary', 'table', 'year', 'who', 'now', 'language', 'full', 'decide', 'right', 'dog', 'paper', 'but', 'chair', 'change', 'hot', 'forget', 'color', 'apple', 'computer', 'cool', 'play', 'cheat', 'white', 'go', 'medicine', 'mother', 'clothes', 'corn', 'want', 'need', 'woman', 'pink', 'deaf', 'many', 'drink', 'family', 'thursday', 'bed', 'candy', 'finish', 'book', 'wrong', 'orange', 'yes', 'shirt', 'what', 'paint', 'enjoy', 'brown', 'dark', 'kiss', 'last', 'doctor', 'city', 'time', 'graduate', 'hearing', 'pizza', 'thanksgiving', 'eat', 'jacket', 'africa', 'thin', 'same', 'bird', 'purple', 'before', 'help', 'dance', 'hat', 'pull', 'can', 'school', 'how', 'all'}

# %%
# Replace 'your_folder_path' with the path to your folder containing the videos
val_folder_path = 'stratified_data/val_data'
val_unique_class_count, val_unique_classes = count_unique_classes(val_folder_path)

print(f"Number of unique validation classes: {val_unique_class_count}")
print("Unique classes:", val_unique_classes)
# Out:
# Number of unique validation classes: 100
# Unique classes: {'basketball', 'blue', 'birthday', 'cook', 'give', 'cow', 'accident', 'bowling', 'no', 'like', 'work', 'meet', 'fine', 'later', 'tall', 'letter', 'study', 'tell', 'walk', 'man', 'short', 'black', 'cousin', 'son', 'fish', 'secretary', 'table', 'year', 'who', 'now', 'language', 'full', 'decide', 'right', 'dog', 'paper', 'but', 'chair', 'change', 'hot', 'forget', 'color', 'apple', 'computer', 'cool', 'play', 'cheat', 'white', 'go', 'medicine', 'mother', 'clothes', 'corn', 'want', 'need', 'woman', 'pink', 'deaf', 'many', 'drink', 'family', 'thursday', 'bed', 'candy', 'finish', 'book', 'wrong', 'orange', 'yes', 'shirt', 'what', 'paint', 'enjoy', 'brown', 'dark', 'kiss', 'last', 'doctor', 'city', 'time', 'graduate', 'hearing', 'pizza', 'thanksgiving', 'eat', 'jacket', 'africa', 'thin', 'same', 'bird', 'purple', 'before', 'help', 'dance', 'hat', 'pull', 'can', 'school', 'how', 'all'}

# %%
# Replace 'your_folder_path' with the path to your folder containing the videos
test_folder_path = 'stratified_data/test_data'
test_unique_class_count, test_unique_classes = count_unique_classes(test_folder_path)

print(f"Number of unique testing classes: {test_unique_class_count}")
print("Unique classes:", test_unique_classes)
# Out:
# Number of unique testing classes: 100
# Unique classes: {'basketball', 'blue', 'birthday', 'cook', 'give', 'cow', 'accident', 'bowling', 'no', 'like', 'work', 'meet', 'fine', 'later', 'tall', 'letter', 'study', 'tell', 'walk', 'man', 'short', 'black', 'cousin', 'son', 'fish', 'secretary', 'table', 'year', 'who', 'now', 'language', 'full', 'decide', 'right', 'dog', 'paper', 'but', 'chair', 'change', 'hot', 'forget', 'color', 'apple', 'computer', 'cool', 'play', 'cheat', 'white', 'go', 'medicine', 'mother', 'clothes', 'corn', 'want', 'need', 'woman', 'pink', 'deaf', 'many', 'drink', 'family', 'thursday', 'bed', 'candy', 'finish', 'book', 'wrong', 'orange', 'yes', 'shirt', 'what', 'paint', 'enjoy', 'brown', 'dark', 'kiss', 'last', 'doctor', 'city', 'time', 'graduate', 'hearing', 'pizza', 'thanksgiving', 'eat', 'jacket', 'africa', 'thin', 'same', 'bird', 'purple', 'before', 'help', 'dance', 'hat', 'pull', 'can', 'school', 'how', 'all'}

# %%
label_data = load_labels(json_file_path)
if label_data is not None:
    rename_videos(data_dir, label_data)
# Out:
# Renamed: organized_data\train_data\69241.mp4 -> organized_data\train_data\book_69241_0.mp4
# ...
# Renamed: organized_data\train_data\07069.mp4 -> organized_data\train_data\book_07069_10.mp4
# ...
# Renamed: organized_data\train_data\07068.mp4 -> organized_data\train_data\book_07068_17.mp4
# ...
# Renamed: organized_data\train_data\07070.mp4 -> organized_data\train_data\book_07070_22.mp4
# ...
# Renamed: organized_data\train_data\07074.mp4 -> organized_data\train_data\book_07074_29.mp4
# ...
# Renamed: organized_data\train_data\17710.mp4 -> organized_data\train_data\drink_17710_11.mp4
# ...
# Renamed: organized_data\train_data\65540.mp4 -> organized_data\train_data\drink_65540_17.mp4
# ...
# Renamed: organized_data\train_data\17711.mp4 -> organized_data\train_data\drink_17711_19.mp4
# Renamed: organized_data\train_data\17712.mp4 -> organized_data\train_data\drink_17712_20.mp4
# ...
# Renamed: organized_data\train_data\17709.mp4 -> organized_data\train_data\drink_17709_27.mp4
# ...

# %% [markdown]
# #### Video information

# %%
def load_video_info(json_file):
    """Loads video information such as FPS and frame range."""
    try:
        with open(json_file, 'r') as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"Error: JSON file '{json_file}' not found.")
        return None
    except json.JSONDecodeError:
        print(f"Error: Invalid JSON format in '{json_file}'.")
        return None

    video_info = {}
    for item in data:
        gloss = item["gloss"]
        for instance in item["instances"]:
            video_id = instance["video_id"]
            fps = instance["fps"]
            frame_start = instance["frame_start"]
            frame_end = instance["frame_end"]
            split = instance["split"]
            instance_id = instance["instance_id"]

            if video_id not in video_info:
                video_info[video_id] = {
                    "gloss": gloss,
                    "fps": fps,
                    "frame_start": frame_start,
                    "frame_end": frame_end,
                    "split": split,
                    "instance_id": instance_id
                }
    return video_info

# %%
# this variable contain the {gloss, fps, frame_start, frame_end, split} information for each instance
video_info = load_video_info(json_file_path)

# %%
print(video_info)
# Out:
# {'69241': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 0}, '65225': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 1}, '68011': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 2}, '68208': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': 60, 'split': 'train', 'instance_id': 3}, '68012': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 4}, '70212': {'gloss': 'book', 'fps': 25, 'frame_start': 2150, 'frame_end': 2249, 'split': 'val', 'instance_id': 5}, '70266': {'gloss': 'book', 'fps': 25, 'frame_start': 3732, 'frame_end': 3852, 'split': 'train', 'instance_id': 6}, '07085': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 7}, '07086': {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'split': 'train', 'instance_id': 8},
# ...

# %%
# the new renaming function

def rename_videos(data_dir, video_info):
    """Renames videos using gloss, video_id, and instance_id from video_info."""
    for subfolder in ["train_data", "val_data", "test_data"]:
        subfolder_path = os.path.join(data_dir, subfolder)
        for video_id, info in video_info.items():
            # Check if the video belongs to the current split
            if info['split'] == subfolder.replace('_data', ''):
                filename = f"{video_id}.mp4"
                old_path = os.path.join(subfolder_path, filename)
                if os.path.exists(old_path):
                    new_filename = f"{info['gloss']}_{video_id}_{info['instance_id']}.mp4"
                    new_path = os.path.join(subfolder_path, new_filename)
                    os.rename(old_path, new_path)
                    print(f"Renamed: {old_path} -> {new_path}")
                else:
                    print(f"Warning: Video file '{filename}' not found in '{subfolder_path}'.")

# %%
rename_videos(data_dir, video_info)
# Out:
# Renamed: organized_data\train_data\69241.mp4 -> organized_data\train_data\book_69241_0.mp4
# ...
# Renamed: organized_data\train_data\07069.mp4 -> organized_data\train_data\book_07069_10.mp4
# ...
# Renamed: organized_data\train_data\07068.mp4 -> organized_data\train_data\book_07068_17.mp4
# ...
# Renamed: organized_data\train_data\07070.mp4 -> organized_data\train_data\book_07070_22.mp4
# ...
# Renamed: organized_data\train_data\07074.mp4 -> organized_data\train_data\book_07074_29.mp4
# ...
# Renamed: organized_data\train_data\17710.mp4 -> organized_data\train_data\drink_17710_11.mp4
# ...
# Renamed: organized_data\train_data\65540.mp4 -> organized_data\train_data\drink_65540_17.mp4
# Renamed: organized_data\train_data\17711.mp4 -> organized_data\train_data\drink_17711_19.mp4
# Renamed: organized_data\train_data\17712.mp4 -> organized_data\train_data\drink_17712_20.mp4
# ...
# Renamed: organized_data\train_data\17709.mp4 -> organized_data\train_data\drink_17709_27.mp4
# ...

# %% [markdown]
# #### Video Renaming

# %%
## renaming videos
import os
import json
#  
json_file_path = 'WLASL_100.json'  
video_folder_path = 'raw_videos_mp4'  
 
with open(json_file_path, 'r') as file:
    data = json.load(file)
 
for gloss_entry in data:
    gloss = gloss_entry["gloss"]
    for instance in gloss_entry["instances"]:
        video_id = instance["video_id"]
        instance_id = instance["instance_id"]
       
        old_file_name = f"{video_id}.mp4"
        new_file_name = f"{gloss}_{video_id}_{instance_id}.mp4"
       
        old_file_path = os.path.join(video_folder_path, old_file_name)
        new_file_path = os.path.join(video_folder_path, new_file_name)
       
        if os.path.exists(old_file_path):
            os.rename(old_file_path, new_file_path)
            print(f"Renamed: {old_file_name} -> {new_file_name}")
        else:
            print(f"File not found: {old_file_name}")
# Out:
# File not found: 69241.mp4
# File not found: 65225.mp4
# File not found: 68011.mp4
# File not found: 68208.mp4
# File not found: 68012.mp4
# File not found: 70212.mp4
# File not found: 70266.mp4
# File not found: 07085.mp4
# File not found: 07086.mp4
# File not found: 07087.mp4
# File not found: 07069.mp4
# File not found: 07088.mp4
# File not found: 07089.mp4
# File not found: 07090.mp4
# File not found: 07091.mp4
# File not found: 07092.mp4
# File not found: 07093.mp4
# File not found: 07068.mp4
# File not found: 07094.mp4
# File not found: 07095.mp4
# File not found: 07096.mp4
# File not found: 07097.mp4
# File not found: 07070.mp4
# File not found: 07098.mp4
# File not found: 07099.mp4
# File not found: 07071.mp4
# File not found: 07072.mp4
# File not found: 07073.mp4
# File not found: 67424.mp4
# File not found: 07074.mp4
# File not found: 07075.mp4
# File not found: 07076.mp4
# File not found: 07077.mp4
# File not found: 07078.mp4
# File not found: 07079.mp4
# ...

# %% [markdown]
# #### Data Splitting

# %%
import os
import shutil
from sklearn.model_selection import train_test_split
 
# Paths
video_folder_path = 'raw_videos_mp4'  # Replace with the folder containing the renamed video files
output_folder_path = 'chaos_data'  # Replace with the desired output folder path
 
# Create directories for split data
train_folder = os.path.join(output_folder_path, 'train_data')
val_folder = os.path.join(output_folder_path, 'val_data')
test_folder = os.path.join(output_folder_path, 'test_data')
 
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)
 
# Prepare a dictionary to group video file paths by gloss
gloss_videos = {}
 
# Group videos by gloss using the filename pattern
for filename in os.listdir(video_folder_path):
    if filename.endswith(".mp4"):
        # Extract gloss from the filename
        gloss = filename.split('_')[0]
        video_path = os.path.join(video_folder_path, filename)
       
        if gloss not in gloss_videos:
            gloss_videos[gloss] = []
        gloss_videos[gloss].append(video_path)
 
# Split and move videos
for gloss, videos in gloss_videos.items():
    if videos:  # Ensure there are videos for this gloss
        train_videos, test_videos = train_test_split(videos, test_size=0.4, random_state=42)
        val_videos, test_videos = train_test_split(test_videos, test_size=0.5, random_state=42)
       
        for video in train_videos:
            shutil.copy(video, os.path.join(train_folder, os.path.basename(video)))
        for video in val_videos:
            shutil.copy(video, os.path.join(val_folder, os.path.basename(video)))
        for video in test_videos:
            shutil.copy(video, os.path.join(test_folder, os.path.basename(video)))
 
print(f"Videos have been split and saved to {output_folder_path}")
# Out:
# Videos have been split and saved to chaos_data

# %%
# check if all classes are present in all folders
def check_classes(data_folder):
    classes = set()
    for filename in os.listdir(data_folder):
        if filename.endswith(".mp4"):
            class_name = filename.split("_")[0]
            classes.add(class_name)
    return classes

# %%
trainLabels = check_classes("stratified_data/test_data") 
print(trainLabels)
print(len(trainLabels))
# Out:
# {'basketball', 'blue', 'birthday', 'cook', 'give', 'cow', 'accident', 'bowling', 'no', 'like', 'work', 'meet', 'fine', 'later', 'tall', 'letter', 'study', 'tell', 'walk', 'man', 'short', 'black', 'cousin', 'son', 'fish', 'secretary', 'table', 'year', 'who', 'now', 'language', 'full', 'decide', 'right', 'dog', 'paper', 'but', 'chair', 'change', 'hot', 'forget', 'color', 'apple', 'computer', 'cool', 'play', 'cheat', 'white', 'go', 'medicine', 'mother', 'clothes', 'corn', 'want', 'need', 'woman', 'pink', 'deaf', 'many', 'drink', 'family', 'thursday', 'bed', 'candy', 'finish', 'book', 'wrong', 'orange', 'yes', 'shirt', 'what', 'paint', 'enjoy', 'brown', 'dark', 'kiss', 'last', 'doctor', 'city', 'time', 'graduate', 'hearing', 'pizza', 'thanksgiving', 'eat', 'jacket', 'africa', 'thin', 'same', 'bird', 'purple', 'before', 'help', 'dance', 'hat', 'pull', 'can', 'school', 'how', 'all'}
# 100

# %%
valLabels = check_classes("stratified_data/val_data")
print(valLabels)
print(len(valLabels))
# Out:
# {'basketball', 'blue', 'birthday', 'cook', 'give', 'cow', 'accident', 'bowling', 'no', 'like', 'work', 'meet', 'fine', 'later', 'tall', 'letter', 'study', 'tell', 'walk', 'man', 'short', 'black', 'cousin', 'son', 'fish', 'secretary', 'table', 'year', 'who', 'now', 'language', 'full', 'decide', 'right', 'dog', 'paper', 'but', 'chair', 'change', 'hot', 'forget', 'color', 'apple', 'computer', 'cool', 'play', 'cheat', 'white', 'go', 'medicine', 'mother', 'clothes', 'corn', 'want', 'need', 'woman', 'pink', 'deaf', 'many', 'drink', 'family', 'thursday', 'bed', 'candy', 'finish', 'book', 'wrong', 'orange', 'yes', 'shirt', 'what', 'paint', 'enjoy', 'brown', 'dark', 'kiss', 'last', 'doctor', 'city', 'time', 'graduate', 'hearing', 'pizza', 'thanksgiving', 'eat', 'jacket', 'africa', 'thin', 'same', 'bird', 'purple', 'before', 'help', 'dance', 'hat', 'pull', 'can', 'school', 'how', 'all'}
# 100

# %%
testLabels = check_classes("stratified_data/test_data")
print(testLabels)
print(len(testLabels))
# Out:
# {'basketball', 'blue', 'birthday', 'cook', 'give', 'cow', 'accident', 'bowling', 'no', 'like', 'work', 'meet', 'fine', 'later', 'tall', 'letter', 'study', 'tell', 'walk', 'man', 'short', 'black', 'cousin', 'son', 'fish', 'secretary', 'table', 'year', 'who', 'now', 'language', 'full', 'decide', 'right', 'dog', 'paper', 'but', 'chair', 'change', 'hot', 'forget', 'color', 'apple', 'computer', 'cool', 'play', 'cheat', 'white', 'go', 'medicine', 'mother', 'clothes', 'corn', 'want', 'need', 'woman', 'pink', 'deaf', 'many', 'drink', 'family', 'thursday', 'bed', 'candy', 'finish', 'book', 'wrong', 'orange', 'yes', 'shirt', 'what', 'paint', 'enjoy', 'brown', 'dark', 'kiss', 'last', 'doctor', 'city', 'time', 'graduate', 'hearing', 'pizza', 'thanksgiving', 'eat', 'jacket', 'africa', 'thin', 'same', 'bird', 'purple', 'before', 'help', 'dance', 'hat', 'pull', 'can', 'school', 'how', 'all'}
# 100

# %%
import os
import shutil
from collections import defaultdict

data_folder_path = 'stratified_data'
train_data_path = os.path.join(data_folder_path, 'train_data')
val_data_path = os.path.join(data_folder_path, 'val_data')
test_data_path = os.path.join(data_folder_path, 'test_data')

os.makedirs(val_data_path, exist_ok=True)
os.makedirs(test_data_path, exist_ok=True)

# group files by gloss in train_data
gloss_files = defaultdict(list)
for filename in os.listdir(train_data_path):
    if filename.endswith(".mp4"):
        # getting the gloss from the filename
        gloss = filename.split('_')[0]
        gloss_files[gloss].append(os.path.join(train_data_path, filename))

for gloss, files in gloss_files.items():
    files.sort() # sort files to ensure consistency 
    if len(files) > 10:
        files_to_copy = files[:2]
    else:
        files_to_copy = files[:1]

    for file in files_to_copy:
        shutil.copy(file, os.path.join(val_data_path, os.path.basename(file)))
        shutil.copy(file, os.path.join(test_data_path, os.path.basename(file)))

        print(f"Copied {os.path.basename(file)} to val_data and test_data")

print("Processing complete.")
# Out:
# Copied accident_00624_2.mp4 to val_data and test_data
# Copied accident_00625_3.mp4 to val_data and test_data
# Copied africa_01384_2.mp4 to val_data and test_data
# Copied all_01987_6.mp4 to val_data and test_data
# Copied apple_02999_13.mp4 to val_data and test_data
# Copied basketball_05230_3.mp4 to val_data and test_data
# Copied bed_05629_3.mp4 to val_data and test_data
# Copied before_05727_20.mp4 to val_data and test_data
# Copied bird_06330_11.mp4 to val_data and test_data
# Copied birthday_06359_11.mp4 to val_data and test_data
# Copied black_06471_14.mp4 to val_data and test_data
# Copied blue_06832_12.mp4 to val_data and test_data
# Copied book_07068_17.mp4 to val_data and test_data
# Copied bowling_07388_13.mp4 to val_data and test_data
# Copied bowling_07389_2.mp4 to val_data and test_data
# Copied brown_07960_13.mp4 to val_data and test_data
# Copied but_08424_11.mp4 to val_data and test_data
# Copied candy_08915_18.mp4 to val_data and test_data
# ...

# %% [markdown]
# #### Loading Video Metadata

# %%
# preparing metadata for feature extraction

def prepare_metadata_for_folder(json_file_path, data_dir, subset_folder):
    """Prepares metadata for a given subset folder (e.g. 'train_data').

    Args:
        json_file_path (str): Path to the JSON file containing annotations (e.g. WLASL_100.json).
        data_dir (str): Path to the directory containing the subset folders.
        subset_folder (str): The name of the subset folder ('train_data', 'val_data', or 'test_data').

    Returns:
        dict: A dictionary mapping video_id to its metadata for that particular subset.
    """
    # Load annotations
    with open(json_file_path, 'r') as f:
        data = json.load(f)

    subset_info = {}
    target_path = os.path.join(data_dir, subset_folder)

    for item in data:
        gloss = item['gloss']
        for instance in item['instances']:
            video_id = instance['video_id']
            fps = instance.get('fps', 25)
            frame_start = instance.get('frame_start', 0)
            frame_end = instance.get('frame_end', -1)
            instance_id = instance['instance_id']

            # Construct the filename
            video_filename = f"{gloss}_{video_id}_{instance_id}.mp4"
            video_path = os.path.join(target_path, video_filename)

            # Check if this video exists in the specified subset folder
            if os.path.exists(video_path):
                subset_info[video_id] = {
                    'gloss': gloss,
                    'fps': fps,
                    'frame_start': frame_start,
                    'frame_end': frame_end,
                    'instance_id': instance_id
                }

    return subset_info

# %%
train_info = prepare_metadata_for_folder('WLASL_100.json', 'stratified_data', 'train_data')
val_info = prepare_metadata_for_folder('WLASL_100.json', 'stratified_data', 'val_data')
test_info = prepare_metadata_for_folder('WLASL_100.json', 'stratified_data', 'test_data')

# %%
# print(test_info)
# print(test_info.get("08431"))
print(len(train_info))
print(len(val_info))
print(len(test_info))

# to_test= {"08426": {'gloss': 'but', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'instance_id': '18', 'split': 'test'}}

# to_val= {"08426": {'gloss': 'but', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'instance_id': '18', 'split': 'val'}, 
#          "07070": {'gloss': 'book', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'instance_id': '22', 'split': 'val'},
#          "64088": {'gloss': 'wrong', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'instance_id': '5', 'split': 'val'},
#          "26715": {'gloss': 'hat', 'fps': 25, 'frame_start': 1, 'frame_end': -1, 'instance_id': '21', 'split': 'val'}}

# test_info.update(to_test)

# val_info.update(to_val)

# print(len(test_info))

# print(len(val_info))
# Out:
# 744
# 409
# 387

# %% [markdown]
# #### Frame extraction

# %%
# Libraries of the section
import cv2

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
def extract_frames(video_path, fps, frame_start, frame_end):
    """Extracts frames from a video, handling variable frame_end values."""
    cap = cv2.VideoCapture(video_path)
    frames = []
    current_frame = 0

    if not cap.isOpened():
        print(f"Error: Could not open video file {video_path}")
        return []

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        if current_frame >= frame_start:
            frames.append(frame)
            if frame_end != -1 and current_frame >= frame_end:
                break  # Stop if frame_end is specified and reached

        current_frame += 1

    cap.release()
    return frames

def downsample_or_upsample_frames(frames, current_fps, target_fps):
    """Downsamples or upsamples frames based on the current and target FPS."""
    if current_fps == target_fps:
        return frames

    if current_fps < target_fps:
        # Upsample: Repeat frames to increase frame rate
        factor = target_fps // current_fps
        new_frames = []
        for frame in frames:
            new_frames.extend([frame] * factor)
        return new_frames
    else:
        # Downsample: Skip frames to decrease frame rate
        factor = current_fps // target_fps
        return frames[::factor]

def create_sequences(frames, sequence_length):
    """Creates sequences of frames from a list of frames."""
    if len(frames) < sequence_length:
        return []  # Return empty list if not enough frames
    sequences = []
    for i in range(len(frames) - sequence_length + 1):
        sequence = frames[i:i + sequence_length]
        sequences.append(sequence)
    return sequences

# %% [markdown]
# #### Features Extraction

# %%
# Libraries of th section

import torch
import torchvision.models as models
import torch.nn as nn
import torchvision.transforms as transforms
import numpy as np

# %%
def extract_resnet_features_batch(frames, resnet_model, transform, device, batch_size=32):
    """Extracts 2048-dimensional ResNet features from a batch of frames."""
    features = []
    batch = []

    for frame in frames:
        img_tensor = transform(frame)  # Transform frame
        batch.append(img_tensor)

        if len(batch) == batch_size:
            batch_tensor = torch.stack(batch).to(device)  # Create batch tensor and move to GPU
            with torch.no_grad():
                outputs = resnet_model(batch_tensor)  # Shape: (batch_size, 2048, 1, 1)
                outputs = outputs.view(outputs.size(0), -1)  # Flatten to (batch_size, 2048)
            features.extend(outputs.cpu().numpy())  # Move features back to CPU
            batch = []  # Reset batch

    # Handle remaining frames
    if batch:
        batch_tensor = torch.stack(batch).to(device)
        with torch.no_grad():
            outputs = resnet_model(batch_tensor)
            outputs = outputs.view(outputs.size(0), -1)
        features.extend(outputs.cpu().numpy())

    return features

def preprocess_and_extract_features(data_dir, split_info, split_type, resnet_model, transform, device, sequence_length=32, target_fps=25, batch_size=32):
    """Preprocesses videos, extracts frames, and features for a specific split."""
    features = []
    labels = []
    
    split_folder = os.path.join(data_dir, f"{split_type}_data")
    
    for video_id, info in split_info.items():
        video_filename = f"{info['gloss']}_{video_id}_{info['instance_id']}.mp4"
        video_path = os.path.join(split_folder, video_filename)
        
        if os.path.exists(video_path):
            frames = extract_frames(video_path, info['fps'], info['frame_start'], info['frame_end'])
            if not frames:
                print(f"No frames extracted from {video_path}. Skipping.")
                continue
            frames = downsample_or_upsample_frames(frames, info['fps'], target_fps)
            sequences = create_sequences(frames, sequence_length)
            
            for sequence in sequences:
                if len(sequence) < sequence_length:
                    continue  # Skip incomplete sequences
                features_seq = extract_resnet_features_batch(sequence, resnet_model, transform, device, batch_size)
                features.append(features_seq)
                labels.append(info['gloss'])
        else:
            print(f"Warning: Video file '{video_path}' not found.")
    
    return features, labels

# %%
# Load ResNet50 and modify
resnet_model = models.resnet50(pretrained=True)
resnet_model = nn.Sequential(*list(resnet_model.children())[:-1])  # Exclude the last layer
resnet_model.to(device)  # Move model to GPU
resnet_model.eval()

# Define transformations
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Out:
# C:\Users\Hayder\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Hayder\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
data_dir = 'stratified_data'

# %%
train_features, train_labels = preprocess_and_extract_features(
    data_dir, train_info, 'train', resnet_model, transform, device,
    sequence_length=16, target_fps=25, batch_size=32
)

# %%
print(f"Training Features Shape: {np.array(train_features).shape}")
print(f"Number of Training Labels: {len(train_labels)}")
print(f"Unique Training Labels: {len(set(train_labels))}")
# Out:
# Training Features Shape: (34905, 16, 2048)
# Number of Training Labels: 34905
# Unique Training Labels: 100

# %%
val_features, val_labels = preprocess_and_extract_features(
    data_dir, val_info, 'val', resnet_model, transform, device,
    sequence_length=16, target_fps=25, batch_size=32
)

# %%
print(f"Validation Features Shape: {np.array(val_features).shape}")
print(f"Number of Validation Labels: {len(val_labels)}")
print(f"Unique Validation Labels: {len(set(val_labels))}")
# Out:
# Validation Features Shape: (20770, 16, 2048)
# Number of Validation Labels: 20770
# Unique Validation Labels: 100

# %%
test_features, test_labels = preprocess_and_extract_features(
    data_dir, test_info, 'test', resnet_model, transform, device,
    sequence_length=16, target_fps=25, batch_size=32
)

# %%
print(f"Testing Features Shape: {np.array(test_features).shape}")
print(f"Number of Testing Labels: {len(test_labels)}")
print(f"Unique Testing Labels: {len(set(test_labels))}")
# Out:
# Testing Features Shape: (19013, 16, 2048)
# Number of Testing Labels: 19013
# Unique Testing Labels: 100

# %%
# np.save("unique_classes.npy", np.unique(unique_classes))

# %%
# Assume all_features and all_labels have been generated by the function
# Save all_features
# np.save('all_features.npy', all_features)
np.save('features_labels/stratified_train_features.npy', train_features)
np.save('features_labels/stratified_val_features.npy', val_features)
np.save('features_labels/stratified_test_features.npy', test_features)


# Save all_labels
# np.save('all_labels.npy', all_labels)
np.save('features_labels/stratified_train_labels.npy', train_labels)
np.save('features_labels/stratified_val_labels.npy', val_labels)
np.save('features_labels/stratified_test_labels.npy', test_labels)

# %%
unique_classes = np.load('features_labels/unique_classes.npy', allow_pickle=True)

# %%
# train_features = np.load('features_labels/train_features.npy', allow_pickle=True)
# train_labels = np.load('features_labels/train_labels.npy', allow_pickle=True)

# %%
# val_features = np.load('features_labels/val_features.npy', allow_pickle=True)
# val_labels = np.load('features_labels/val_labels.npy', allow_pickle=True)

# %%
# test_features = np.load('features_labels/test_features.npy', allow_pickle=True)
# test_labels = np.load('features_labels/test_labels.npy', allow_pickle=True)

# %%
#from temp npy files

# train_features = np.load('train_features_temp.npy', allow_pickle=True)
# train_encoded_labels = np.load('train_labels_encoded_temp.npy', allow_pickle=True)

# val_features = np.load('val_features_temp.npy', allow_pickle=True)
# val_encoded_labels = np.load('val_labels_encoded_temp.npy', allow_pickle=True)

# test_features = np.load('test_features_temp.npy', allow_pickle=True)
# test_encoded_labels = np.load('test_labels_encoded_temp.npy', allow_pickle=True)

# %%
print(set.difference(set(train_labels), set(val_labels)))
print("\n",set.difference(set(train_labels), set(test_labels)))
# Out:
# set()
#
#  set()

# %% [markdown]
# #### Labels Encoding

# %%
# Libraries of the section
from torch.utils.data import Dataset
import torchvision.transforms as transforms
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import LabelEncoder

# %%
batch_size = 32 # Adjust based on your system's capacity

# %%
label_encoder = LabelEncoder()

label_encoder.fit(list(unique_classes[0]))
# Out:
# LabelEncoder()

# %%
train_encoded_labels = label_encoder.transform(train_labels)

# Convert to tensors
features_tensor = torch.tensor(train_features, dtype=torch.float32)
labels_tensor = torch.tensor(train_encoded_labels, dtype=torch.long)

# Create a TensorDataset and DataLoader
train_dataset = TensorDataset(features_tensor, labels_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
# Out:
# C:\Users\Hayder\AppData\Local\Temp\ipykernel_22332\2725627781.py:4: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:281.)
#   features_tensor = torch.tensor(train_features, dtype=torch.float32)

# %%
val_encoded_labels = label_encoder.transform(val_labels)

# Convert to tensors
val_features_tensor = torch.tensor(val_features, dtype=torch.float32)
val_labels_tensor = torch.tensor(val_encoded_labels, dtype=torch.long)

# Create a TensorDataset and DataLoader
val_dataset = TensorDataset(val_features_tensor, val_labels_tensor)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
test_encoded_labels = label_encoder.transform(test_labels)

# Convert to tensors
test_features_tensor = torch.tensor(test_features, dtype=torch.float32)
test_labels_tensor = torch.tensor(test_encoded_labels, dtype=torch.long)

# Create a TensorDataset and DataLoader
test_dataset = TensorDataset(test_features_tensor, test_labels_tensor)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ### LSTM Model Definition

# %%
import torch
import torch.nn as nn

import torch
import torch.nn as nn
import torch.nn.functional as F

class SignLanguageLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes, num_layers=1, dropout=0.5):
        super(SignLanguageLSTM, self).__init__()

        # Bidirectional LSTM with reduced hidden size and layers
        self.lstm = nn.LSTM(
            input_size, hidden_size, num_layers,
            batch_first=True, bidirectional=True
        )

        # Layer normalization
        self.layer_norm = nn.LayerNorm(hidden_size * 2)

        # Fully connected layers with gradual dimension reduction
        self.fc1 = nn.Linear(hidden_size * 2, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, num_classes)

        # Dropout layer
        self.dropout = nn.Dropout(dropout)

        # Initialize weights
        self.init_weights()

    def forward(self, x):
        # LSTM forward pass
        lstm_out, _ = self.lstm(x)

        # Apply LayerNorm to LSTM outputs
        lstm_out = self.layer_norm(lstm_out)

        # Mean pooling over time steps
        out = torch.mean(lstm_out, dim=1)

        # Apply dropout
        out = self.dropout(out)

        # Fully connected layers with activation functions
        out = F.relu(self.fc1(out))
        out = self.dropout(out)
        out = F.relu(self.fc2(out))
        out = self.fc3(out)

        return out

    def init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.LSTM):
                for name, param in m.named_parameters():
                    if 'weight' in name:
                        nn.init.xavier_uniform_(param)
                    elif 'bias' in name:
                        nn.init.zeros_(param)

# %% [markdown]
# #### Training loop

# %%
def train_and_evaluate_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=20, patience=5, use_early_stopping=True):
    """ Train and evaluate the model.
    
    Args:
        model: The neural network model to train.
        train_loader: DataLoader for the training dataset.
        val_loader: DataLoader for the validation dataset.
        criterion: The loss function.
        optimizer: The optimizer for model training.
        num_epochs: Number of epochs for training (default is 20).
        patience: Number of epochs to wait for improvement before early stopping (default is 5).
        use_early_stopping: Whether to use early stopping (default is True).

    Returns:
        Lists of training losses, validation losses, training accuracies, and validation accuracies.
    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    best_val_loss = float('inf')
    epochs_without_improvement = 0
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_predictions = 0
        total_predictions = 0

        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item() * features.size(0)
            _, predicted = torch.max(outputs, 1)
            correct_predictions += (predicted == labels).sum().item()
            total_predictions += labels.size(0)

        epoch_loss = running_loss / total_predictions
        epoch_accuracy = correct_predictions / total_predictions
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_accuracy)

        model.eval()
        val_running_loss = 0.0
        val_correct_predictions = 0
        val_total_predictions = 0

        with torch.no_grad():
            for val_features, vali_labels in val_loader:
                val_features, vali_labels = val_features.to(device), vali_labels.to(device)
                val_outputs = model(val_features)
                val_loss = criterion(val_outputs, vali_labels)
                val_running_loss += val_loss.item() * val_features.size(0)
                _, val_predicted = torch.max(val_outputs, 1)
                val_correct_predictions += (val_predicted == vali_labels).sum().item()
                val_total_predictions += vali_labels.size(0)

        val_epoch_loss = val_running_loss / val_total_predictions
        val_epoch_accuracy = val_correct_predictions / val_total_predictions
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_accuracy)

        print(f"Epoch [{epoch + 1}/{num_epochs}], "
              f"Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_accuracy:.4f}, "
              f"Val Loss: {val_epoch_loss:.4f}, Val Accuracy: {val_epoch_accuracy:.4f}")

        if use_early_stopping:
            min_delta = 0.1  # Minimum change in loss to qualify as an improvement
            if val_epoch_loss < (best_val_loss - min_delta):
                best_val_loss = val_epoch_loss
                epochs_without_improvement = 0
            else:
                epochs_without_improvement += 1
                if epochs_without_improvement >= patience:
                    print("Early stopping triggered. Stopping training.")
                    break

    return train_losses, val_losses, train_accuracies, val_accuracies

# %% [markdown]
# ### Hyperparameters of the model & Model Initialization

# %%
input_size = 2048  # This matches the feature size from your ResNet
hidden_size = 512 #{256,512}
num_classes = 100  # Number of unique classes
num_layers = 3 #{2,3}
dropout = 0.5 #{0.2, 0.3, 0.4, 0.5}

# Initialize the model
model = SignLanguageLSTM(input_size, hidden_size, num_classes, num_layers, dropout)

# Loss function and optimizer
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-3)

# %%
# Train the model
train_losses, val_losses, train_accuracies, val_accuracies = train_and_evaluate_model(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    num_epochs=20,
    patience=3,
    use_early_stopping=True
)
# Out:
# Epoch [1/20], Train Loss: 4.6156, Train Accuracy: 0.0132, Val Loss: 4.5946, Val Accuracy: 0.0192
# Epoch [2/20], Train Loss: 4.5553, Train Accuracy: 0.0221, Val Loss: 4.5578, Val Accuracy: 0.0398
# Epoch [3/20], Train Loss: 4.3378, Train Accuracy: 0.0584, Val Loss: 4.2428, Val Accuracy: 0.1040
# Epoch [4/20], Train Loss: 3.7842, Train Accuracy: 0.1656, Val Loss: 3.5464, Val Accuracy: 0.2961
# Epoch [5/20], Train Loss: 2.9695, Train Accuracy: 0.3640, Val Loss: 3.0799, Val Accuracy: 0.4587
# Epoch [6/20], Train Loss: 2.2842, Train Accuracy: 0.5707, Val Loss: 2.6641, Val Accuracy: 0.6031
# Epoch [7/20], Train Loss: 1.7943, Train Accuracy: 0.7368, Val Loss: 2.4431, Val Accuracy: 0.7020
# Epoch [8/20], Train Loss: 1.4959, Train Accuracy: 0.8412, Val Loss: 2.2787, Val Accuracy: 0.7364
# Epoch [9/20], Train Loss: 1.3297, Train Accuracy: 0.8952, Val Loss: 2.1854, Val Accuracy: 0.7579
# Epoch [10/20], Train Loss: 1.2227, Train Accuracy: 0.9271, Val Loss: 2.1527, Val Accuracy: 0.7683
# ...

# %% [markdown]
# #### Plots

# %%
import matplotlib.pyplot as plt
 
# Plot loss
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
 
# Plot accuracy
plt.figure(figsize=(10, 5))
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.title('Accuracy vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Testing the model

# %%
def evaluate_model(model, loader):
    model.eval()
    correct = 0
    total = 0
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)
    accuracy = correct / total
    return accuracy

# %%
test_accuracy = evaluate_model(model, test_loader)*100
print(f"Test accuracy: {test_accuracy:.4f}%")
# Out:
# Test accuracy: 76.5213%

# %%
print(device)
torch.cuda.empty_cache()
# Out:
# cuda

# %% [markdown]
# ### Possible Causes of Model Limitations
#
# - Video being too short to extract enough features
# - Loosing many videos due to corrupted mp4 files and not-working video links
# - The computational cost to extract the features and train the model
# - The level of difficulty between [training, validation, testing] samples is not the same
